# %%
import spacy
from spacy import displacy
import numpy as np
from IPython.core.debugger import set_trace
import os
import pdb

save_dir = "features"
if not os.path.exists(save_dir):
    os.mkdir(save_dir)
    
nlp = spacy.load("en_core_web_lg")

# %%
hp_text = open("chapter9.txt","r").readlines()
all_text = []
para = ""
for i in range(len(hp_text)):
    hp_text[i] = hp_text[i].strip()
    if hp_text[i]!="+":
        para += hp_text[i] + " "
    else:
        all_text.append(para)
        para = ""

# %%
all_vecs = []
for i in range(len(hp_text)):
    all_vecs.append([])

ind = 0
rem_len = len(hp_text[ind])
for para in all_text:
    proc = nlp(para)
    for word in proc:
        all_vecs[ind].append(word.ent_type_)
        rem_len -= len(word.text)
        if rem_len <= 0:
            ind += 1
            while(ind < len(hp_text) and hp_text[ind] == "+"):
                ind += 1
            if ind < len(hp_text):
                rem_len = len(hp_text[ind]) + rem_len
c = [[hp_text[i],all_vecs[i]] for i in range(5176)]
for i in c:
    print(i)
# Out:
# ['Harry', ['PERSON']]
# ['had', ['']]
# ['never', ['']]
# ['believed', ['']]
# ['he', ['']]
# ['would', ['']]
# ['meet', ['']]
# ['a', ['']]
# ['boy', ['']]
# ['he', ['']]
# ['hated', ['']]
# ['more', ['']]
# ['than', ['']]
# ['Dudley,', ['PERSON', '']]
# ['but', ['']]
# ['that', ['']]
# ['was', ['']]
# ['before', ['']]
# ['he', ['']]
# ['met', ['']]
# ['Draco', ['PERSON']]
# ['Malfoy.', ['PERSON', '']]
# ['Still,', ['', '']]
# ['first-year', ['DATE', 'DATE', 'DATE']]
# ['Gryffindors', ['PERSON']]
# ['only', ['']]
# ['had', ['']]
# ['Potions', ['PRODUCT']]
# ['with', ['']]
# ['the', ['']]
# ['Slytherins,', ['NORP', '']]
# ['so', ['']]
# ['they', ['']]
# ["didn't", ['', '']]
# ['have', ['']]
# ['to', ['']]
# ['put', ['']]
# ['up', ['']]
# ['with', ['']]
# ['Malfoy', ['PERSON']]
# ['much.', ['', '']]
# ['Or', ['']]
# ['at', ['']]
# ['least,', ['', '']]
# ['they', ['']]
# ["didn't", ['', '']]
# ['until', ['']]
# ['they', ['']]
# ['spotted', ['']]
# ['a', ['']]
# ['notice', ['']]
# ['pinned', ['']]
# ['up', ['']]
# ['in', ['']]
# ['the', ['']]
# ['Gryffindor', ['']]
# ['common', ['']]
# ['room', ['']]
# ['that', ['']]
# ['made', ['']]
# ['them', ['']]
# ['all', ['']]
# ['groan.', ['', '']]
# ['Flying', ['']]
# ['lessons', ['']]
# ['would', ['']]
# ['be', ['']]
# ['starting', ['']]
# ['on', ['']]
# ['Thursday', ['DATE']]
# ['--', ['']]
# ['and', ['']]
# ['Gryffindor', ['PERSON']]
# ['and', ['']]
# ['Slytherin', ['']]
# ['would', ['']]
# ['be', ['']]
# ['learning', ['']]
# ['together.', ['', '']]
# ['+', []]
# ['"Typical,"', ['', '', '', '']]
# ['said', ['']]
# ['Harry', ['PERSON']]
# ['darkly.', ['', '']]
# ['"Just', ['', '']]
# ['what', ['']]
# ['I', ['']]
# ['always', ['']]
# ['wanted.', ['', '']]
# ['To', ['']]
# ['make', ['']]
# ['a', ['']]
# ['fool', ['']]
# ['of', ['']]
# ['myself', ['']]
# ['on', ['']]
# ['a', ['']]
# ['broomstick', ['']]
# ['in', ['']]
# ['front', ['']]
# ['of', ['']]
# ['Malfoy."', ['PERSON', '', '']]
# ['+', []]
# ['He', ['']]
# ['had', ['']]
# ['been', ['']]
# ['looking', ['']]
# ['forward', ['']]
# ['to', ['']]
# ['learning', ['']]
# ['to', ['']]
# ['fly', ['']]
# ['more', ['']]
# ['than', ['']]
# ['anything', ['']]
# ['else.', ['', '']]
# ['"You', ['', '']]
# ["don't", ['', '']]
# ['know', ['']]
# ['that', ['']]
# ["you'll", ['', '']]
# ['make', ['']]
# ['a', ['']]
# ['fool', ['']]
# ['of', ['']]
# ['yourself,"', ['', '', '']]
# ['said', ['']]
# ['Ron', ['PERSON']]
# ['reasonably.', ['', '']]
# ['"Anyway,', ['', '', '']]
# ['I', ['']]
# ['know', ['']]
# ["Malfoy's", ['', '']]
# ['always', ['']]
# ['going', ['']]
# ['on', ['']]
# ['about', ['']]
# ['how', ['']]
# ['good', ['']]
# ['he', ['']]
# ['is', ['']]
# ['at', ['']]
# ['Quidditch,', ['ORG', '']]
# ['but', ['']]
# ['I', ['']]
# ['bet', ['']]
# ["that's", ['', '']]
# ['all', ['']]
# ['talk."', ['', '', '']]
# ['+', []]
# ['Malfoy', ['PERSON']]
# ['certainly', ['']]
# ['did', ['']]
# ['talk', ['']]
# ['about', ['']]
# ['flying', ['']]
# ['a', ['']]
# ['lot.', ['', '']]
# ['He', ['']]
# ['complained', ['']]
# ['loudly', ['']]
# ['about', ['DATE']]
# ['first', ['DATE']]
# ['years', ['DATE']]
# ['never', ['']]
# ['getting', ['']]
# ['on', ['']]
# ['the', ['']]
# ['House', ['ORG']]
# ['Quidditch', ['']]
# ['teams', ['']]
# ['and', ['']]
# ['told', ['']]
# ['long,', ['', '']]
# ['boastful', ['']]
# ['stories', ['']]
# ['that', ['']]
# ['always', ['']]
# ['seemed', ['']]
# ['to', ['']]
# ['end', ['']]
# ['with', ['']]
# ['him', ['']]
# ['narrowly', ['']]
# ['escaping', ['']]
# ['Muggles', ['']]
# ['in', ['']]
# ['helicopters.', ['', '']]
# ['He', ['']]
# ["wasn't", ['', '']]
# ['the', ['']]
# ['only', ['']]
# ['one,', ['', '']]
# ['though:', ['', '']]
# ['the', ['']]
# ['way', ['']]
# ['Seamus', ['PERSON']]
# ['Finnigan', ['PERSON']]
# ['told', ['']]
# ['it,', ['', '']]
# ["he'd", ['', '']]
# ['spent', ['']]
# ['most', ['']]
# ['of', ['']]
# ['his', ['']]
# ['childhood', ['']]
# ['zooming', ['']]
# ['around', ['']]
# ['the', ['']]
# ['countryside', ['']]
# ['on', ['']]
# ['his', ['']]
# ['broomstick.', ['', '']]
# ['Even', ['']]
# ['Ron', ['PERSON']]
# ['would', ['']]
# ['tell', ['']]
# ['anyone', ['']]
# ["who'd", ['', '']]
# ['listen', ['']]
# ['about', ['']]
# ['the', ['']]
# ['time', ['']]
# ["he'd", ['', '']]
# ['almost', ['']]
# ['hit', ['']]
# ['a', ['']]
# ['hang', ['']]
# ['glider', ['']]
# ['on', ['']]
# ["Charlie's", ['PERSON', '']]
# ['old', ['']]
# ['broom.', ['', '']]
# ['Everyone', ['']]
# ['from', ['']]
# ['wizarding', ['']]
# ['families', ['']]
# ['talked', ['']]
# ['about', ['']]
# ['Quidditch', ['ORG']]
# ['constantly.', ['', '']]
# ['Ron', ['PERSON']]
# ['had', ['']]
# ['already', ['']]
# ['had', ['']]
# ['a', ['']]
# ['big', ['']]
# ['argument', ['']]
# ['with', ['']]
# ['Dean', ['PERSON']]
# ['Thomas,', ['PERSON', '']]
# ['who', ['']]
# ['shared', ['']]
# ['their', ['']]
# ['dormitory,', ['', '']]
# ['about', ['']]
# ['soccer.', ['', '']]
# ['Ron', ['PERSON']]
# ["couldn't", ['', '']]
# ['see', ['']]
# ['what', ['']]
# ['was', ['']]
# ['exciting', ['']]
# ['about', ['']]
# ['a', ['']]
# ['game', ['']]
# ['with', ['']]
# ['only', ['']]
# ['one', ['']]
# ['ball', ['']]
# ['where', ['']]
# ['no', ['']]
# ['one', ['']]
# ['was', ['']]
# ['allowed', ['']]
# ['to', ['']]
# ['fly.', ['', '']]
# ['Harry', ['PERSON']]
# ['had', ['']]
# ['caught', ['']]
# ['Ron', ['PERSON']]
# ['prodding', ['']]
# ["Dean's", ['PERSON', '']]
# ['poster', ['']]
# ['of', ['']]
# ['West', ['NORP']]
# ['Ham', ['NORP']]
# ['soccer', ['']]
# ['team,', ['', '']]
# ['trying', ['']]
# ['to', ['']]
# ['make', ['']]
# ['the', ['']]
# ['players', ['']]
# ['move.', ['', '']]
# ['+', []]
# ['Neville', ['PERSON']]
# ['had', ['']]
# ['never', ['']]
# ['been', ['']]
# ['on', ['']]
# ['a', ['']]
# ['broomstick', ['']]
# ['in', ['']]
# ['his', ['']]
# ['life,', ['', '']]
# ['because', ['']]
# ['his', ['']]
# ['grandmother', ['']]
# ['had', ['']]
# ['never', ['']]
# ['let', ['']]
# ['him', ['']]
# ['near', ['']]
# ['one.', ['', '']]
# ['Privately,', ['', '']]
# ['Harry', ['PERSON']]
# ['felt', ['']]
# ["she'd", ['', '']]
# ['had', ['']]
# ['good', ['']]
# ['reason,', ['', '']]
# ['because', ['']]
# ['Neville', ['PERSON']]
# ['managed', ['']]
# ['to', ['']]
# ['have', ['']]
# ['an', ['']]
# ['extraordinary', ['']]
# ['number', ['']]
# ['of', ['']]
# ['accidents', ['']]
# ['even', ['']]
# ['with', ['']]
# ['both', ['']]
# ['feet', ['']]
# ['on', ['']]
# ['the', ['']]
# ['ground.', ['', '']]
# ['+', []]
# ['Hermione', ['PERSON']]
# ['Granger', ['PERSON']]
# ['was', ['']]
# ['almost', ['']]
# ['as', ['']]
# ['nervous', ['']]
# ['about', ['']]
# ['flying', ['']]
# ['as', ['']]
# ['Neville', ['PERSON']]
# ['was.', ['', '']]
# ['This', ['']]
# ['was', ['']]
# ['something', ['']]
# ['you', ['']]
# ["couldn't", ['', '']]
# ['learn', ['']]
# ['by', ['']]
# ['heart', ['']]
# ['out', ['']]
# ['of', ['']]
# ['a', ['']]
# ['book', ['']]
# ['--', ['']]
# ['not', ['']]
# ['that', ['']]
# ['she', ['']]
# ["hadn't", ['', '']]
# ['tried.', ['', '']]
# ['At', ['']]
# ['breakfast', ['']]
# ['on', ['']]
# ['Thursday', ['DATE']]
# ['she', ['']]
# ['bored', ['']]
# ['them', ['']]
# ['all', ['']]
# ['stupid', ['']]
# ['with', ['']]
# ['flying', ['']]
# ['tips', ['']]
# ["she'd", ['', '']]
# ['gotten', ['']]
# ['out', ['']]
# ['of', ['']]
# ['a', ['']]
# ['library', ['']]
# ['book', ['']]
# ['called', ['']]
# ['Quidditch', ['WORK_OF_ART']]
# ['Through', ['WORK_OF_ART']]
# ['the', ['WORK_OF_ART']]
# ['Ages.', ['WORK_OF_ART', '']]
# ['Neville', ['PERSON']]
# ['was', ['']]
# ['hanging', ['']]
# ['on', ['']]
# ['to', ['']]
# ['her', ['']]
# ['every', ['']]
# ['word,', ['', '']]
# ['desperate', ['']]
# ['for', ['']]
# ['anything', ['']]
# ['that', ['']]
# ['might', ['']]
# ['help', ['']]
# ['him', ['']]
# ['hang', ['']]
# ['on', ['']]
# ['to', ['']]
# ['his', ['']]
# ['broomstick', ['']]
# ['later,', ['', '']]
# ['but', ['']]
# ['everybody', ['']]
# ['else', ['']]
# ['was', ['']]
# ['very', ['']]
# ['pleased', ['']]
# ['when', ['']]
# ["Hermione's", ['PERSON', '']]
# ['lecture', ['']]
# ['was', ['']]
# ['interrupted', ['']]
# ['by', ['']]
# ['the', ['']]
# ['arrival', ['']]
# ['of', ['']]
# ['the', ['']]
# ['mail.', ['', '']]
# ['+', []]
# ['Harry', ['PERSON']]
# ["hadn't", ['', '']]
# ['had', ['']]
# ['a', ['']]
# ['single', ['']]
# ['letter', ['']]
# ['since', ['']]
# ["Hagrid's", ['', '']]
# ['note,', ['', '']]
# ['something', ['']]
# ['that', ['']]
# ['Malfoy', ['PERSON']]
# ['had', ['']]
# ['been', ['']]
# ['quick', ['']]
# ['to', ['']]
# ['notice,', ['', '']]
# ['of', ['']]
# ['course.', ['', '']]
# ["Malfoy's", ['PERSON', '']]
# ['eagle', ['']]
# ['owl', ['']]
# ['was', ['']]
# ['always', ['']]
# ['bringing', ['']]
# ['him', ['']]
# ['packages', ['']]
# ['of', ['']]
# ['sweets', ['']]
# ['from', ['']]
# ['home,', ['', '']]
# ['which', ['']]
# ['he', ['']]
# ['opened', ['']]
# ['gloatingly', ['']]
# ['at', ['']]
# ['the', ['']]
# ['Slytherin', ['']]
# ['table.', ['', '']]
# ['+', []]
# ['A', ['']]
# ['barn', ['']]
# ['owl', ['']]
# ['brought', ['']]
# ['Neville', ['PERSON']]
# ['a', ['']]
# ['small', ['']]
# ['package', ['']]
# ['from', ['']]
# ['his', ['']]
# ['grandmother.', ['', '']]
# ['He', ['']]
# ['opened', ['']]
# ['it', ['']]
# ['excitedly', ['']]
# ['and', ['']]
# ['showed', ['']]
# ['them', ['']]
# ['a', ['']]
# ['glass', ['']]
# ['ball', ['']]
# ['the', ['']]
# ['size', ['']]
# ['of', ['']]
# ['a', ['']]
# ['large', ['']]
# ['marble,', ['', '']]
# ['which', ['']]
# ['seemed', ['']]
# ['to', ['']]
# ['be', ['']]
# ['full', ['']]
# ['of', ['']]
# ['white', ['']]
# ['smoke.', ['', '']]
# ['+', []]
# ['"It\'s', ['', '', '']]
# ['a', ['']]
# ['Remembrall!"', ['', '', '']]
# ['he', ['']]
# ['explained.', ['', '']]
# ['"Gran', ['', 'WORK_OF_ART']]
# ['knows', ['']]
# ['I', ['']]
# ['forget', ['']]
# ['things', ['']]
# ['--', ['']]
# ['this', ['']]
# ['tells', ['']]
# ['you', ['']]
# ['if', ['']]
# ["there's", ['', '']]
# ['something', ['']]
# ["you've", ['', '']]
# ['forgotten', ['']]
# ['to', ['']]
# ['do.', ['', '']]
# ['Look,', ['', '']]
# ['you', ['']]
# ['hold', ['']]
# ['it', ['']]
# ['tight', ['']]
# ['like', ['']]
# ['this', ['']]
# ['and', ['']]
# ['if', ['']]
# ['it', ['']]
# ['turns', ['']]
# ['red', ['']]
# ['--', ['']]
# ['oh', ['']]
# ['..."', ['', '']]
# ['His', ['']]
# ['face', ['']]
# ['fell,', ['', '']]
# ['because', ['']]
# ['the', ['']]
# ['Remembrall', ['PERSON']]
# ['had', ['']]
# ['suddenly', ['']]
# ['glowed', ['']]
# ['scarlet,', ['', '']]
# ['"...', ['', '']]
# ["you've", ['', '']]
# ['forgotten', ['']]
# ['something', ['']]
# ['..."', ['', '']]
# ['+', []]
# ['Neville', ['PERSON']]
# ['was', ['']]
# ['trying', ['']]
# ['to', ['']]
# ['remember', ['']]
# ['what', ['']]
# ["he'd", ['', '']]
# ['forgotten', ['']]
# ['when', ['']]
# ['Draco', ['PERSON']]
# ['Malfoy,', ['PERSON', '']]
# ['who', ['']]
# ['was', ['']]
# ['passing', ['']]
# ['the', ['']]
# ['Gryffindor', ['']]
# ['table,', ['', '']]
# ['snatched', ['']]
# ['the', ['']]
# ['Remembrall', ['PERSON']]
# ['out', ['']]
# ['of', ['']]
# ['his', ['']]
# ['hand.', ['', '']]
# ['+', []]
# ['Harry', ['PERSON']]
# ['and', ['']]
# ['Ron', ['PERSON']]
# ['jumped', ['']]
# ['to', ['']]
# ['their', ['']]
# ['feet.', ['', '']]
# ['They', ['']]
# ['were', ['']]
# ['half', ['']]
# ['hoping', ['']]
# ['for', ['']]
# ['a', ['']]
# ['reason', ['']]
# ['to', ['']]
# ['fight', ['']]
# ['Malfoy,', ['PERSON', '']]
# ['but', ['']]
# ['Professor', ['']]
# ['McGonagall,', ['PERSON', '']]
# ['who', ['']]
# ['could', ['']]
# ['spot', ['']]
# ['trouble', ['']]
# ['quicker', ['']]
# ['than', ['']]
# ['any', ['']]
# ['teacher', ['']]
# ['in', ['']]
# ['the', ['']]
# ['school,', ['', '']]
# ['was', ['']]
# ['there', ['']]
# ['in', ['']]
# ['a', ['']]
# ['flash.', ['', '']]
# ['+', []]
# ['"What\'s', ['', '', '']]
# ['going', ['']]
# ['on?"', ['', '', '']]
# ['+', []]
# ['"Malfoy\'s', ['', 'PERSON', '']]
# ['got', ['']]
# ['my', ['']]
# ['Remembrall,', ['PERSON', '']]
# ['Professor."', ['', '', '']]
# ['+', []]
# ['Scowling,', ['', '']]
# ['Malfoy', ['PERSON']]
# ['quickly', ['']]
# ['dropped', ['']]
# ['the', ['']]
# ['Remembrall', ['PERSON']]
# ['back', ['']]
# ['on', ['']]
# ['the', ['']]
# ['table.', ['', '']]
# ['+', []]
# ['"Just', ['', '']]
# ['looking,"', ['', '', '']]
# ['he', ['']]
# ['said,', ['', '']]
# ['and', ['']]
# ['he', ['']]
# ['sloped', ['']]
# ['away', ['']]
# ['with', ['']]
# ['Crabbe', ['PERSON']]
# ['and', ['']]
# ['Goyle', ['PERSON']]
# ['behind', ['']]
# ['him.', ['', '']]
# ['+', []]
# ['+', []]
# ['At', ['']]
# ['three-thirty', ['CARDINAL', 'CARDINAL', 'CARDINAL']]
# ['that', ['']]
# ['afternoon,', ['', '']]
# ['Harry,', ['PERSON', '']]
# ['Ron,', ['PERSON', '']]
# ['and', ['']]
# ['the', ['']]
# ['other', ['']]
# ['Gryffindors', ['ORG']]
# ['hurried', ['']]
# ['down', ['']]
# ['the', ['']]
# ['front', ['']]
# ['steps', ['']]
# ['onto', ['']]
# ['the', ['']]
# ['grounds', ['']]
# ['for', ['']]
# ['their', ['']]
# ['first', ['ORDINAL']]
# ['flying', ['']]
# ['lesson.', ['', '']]
# ['It', ['']]
# ['was', ['']]
# ['a', ['']]
# ['clear,', ['', '']]
# ['breezy', ['']]
# ['day,', ['', '']]
# ['and', ['']]
# ['the', ['']]
# ['grass', ['']]
# ['rippled', ['']]
# ['under', ['']]
# ['their', ['']]
# ['feet', ['']]
# ['as', ['']]
# ['they', ['']]
# ['marched', ['']]
# ['down', ['']]
# ['the', ['']]
# ['sloping', ['']]
# ['lawns', ['']]
# ['toward', ['']]
# ['a', ['']]
# ['smooth,', ['', '']]
# ['flat', ['']]
# ['lawn', ['']]
# ['on', ['']]
# ['the', ['']]
# ['opposite', ['']]
# ['side', ['']]
# ['of', ['']]
# ['the', ['']]
# ['grounds', ['']]
# ['to', ['']]
# ['the', ['']]
# ['forbidden', ['']]
# ['forest,', ['', '']]
# ['whose', ['']]
# ['trees', ['']]
# ['were', ['']]
# ['swaying', ['']]
# ['darkly', ['']]
# ['in', ['']]
# ['the', ['']]
# ['distance.', ['', '']]
# ['+', []]
# ['The', ['']]
# ['Slytherins', ['NORP']]
# ['were', ['']]
# ['already', ['']]
# ['there,', ['', '']]
# ['and', ['']]
# ['so', ['']]
# ['were', ['']]
# ['twenty', ['CARDINAL']]
# ['broomsticks', ['']]
# ['lying', ['']]
# ['in', ['']]
# ['neat', ['']]
# ['lines', ['']]
# ['on', ['']]
# ['the', ['']]
# ['ground.', ['', '']]
# ['Harry', ['PERSON']]
# ['had', ['']]
# ['heard', ['']]
# ['Fred', ['']]
# ['and', ['']]
# ['George', ['PERSON']]
# ['Weasley', ['PERSON']]
# ['complain', ['']]
# ['about', ['']]
# ['the', ['']]
# ['school', ['']]
# ['brooms,', ['', '']]
# ['saying', ['']]
# ['that', ['']]
# ['some', ['']]
# ['of', ['']]
# ['them', ['']]
# ['started', ['']]
# ['to', ['']]
# ['vibrate', ['']]
# ['if', ['']]
# ['you', ['']]
# ['flew', ['']]
# ['too', ['']]
# ['high,', ['', '']]
# ['or', ['']]
# ['always', ['']]
# ['flew', ['']]
# ['slightly', ['']]
# ['to', ['']]
# ['the', ['']]
# ['left.', ['', '']]
# ['+', []]
# ['Their', ['']]
# ['teacher,', ['', '']]
# ['Madam', ['']]
# ['Hooch,', ['PERSON', '']]
# ['arrived.', ['', '']]
# ['She', ['']]
# ['had', ['']]
# ['short,', ['', '']]
# ['gray', ['']]
# ['hair,', ['', '']]
# ['and', ['']]
# ['yellow', ['']]
# ['eyes', ['']]
# ['like', ['']]
# ['a', ['']]
# ['hawk.', ['', '']]
# ['+', []]
# ['"Well,', ['', '', '']]
# ['what', ['']]
# ['are', ['']]
# ['you', ['']]
# ['all', ['']]
# ['waiting', ['']]
# ['for?"', ['', '', '']]
# ['she', ['']]
# ['barked.', ['', '']]
# ['"Everyone', ['', '']]
# ['stand', ['']]
# ['by', ['']]
# ['a', ['']]
# ['broomstick.', ['', '']]
# ['Come', ['']]
# ['on,', ['', '']]
# ['hurry', ['']]
# ['up."', ['', '', '']]
# ['+', []]
# ['Harry', ['PERSON']]
# ['glanced', ['']]
# ['down', ['']]
# ['at', ['']]
# ['his', ['']]
# ['broom.', ['', '']]
# ['It', ['']]
# ['was', ['']]
# ['old', ['']]
# ['and', ['']]
# ['some', ['']]
# ['of', ['']]
# ['the', ['']]
# ['twigs', ['']]
# ['stuck', ['']]
# ['out', ['']]
# ['at', ['']]
# ['odd', ['']]
# ['angles.', ['', '']]
# ['+', []]
# ['"Stick', ['', 'FAC']]
# ['out', ['']]
# ['your', ['']]
# ['right', ['']]
# ['hand', ['']]
# ['over', ['']]
# ['your', ['']]
# ['broom,"', ['', '', '']]
# ['called', ['']]
# ['Madam', ['']]
# ['Hooch', ['PERSON']]
# ['at', ['']]
# ['the', ['']]
# ['front,', ['', '']]
# ['"and', ['', '']]
# ['say', ['']]
# ['\'Up!\'"', ['', '', '', '', '']]
# ['+', []]
# ['"UP!"', ['', '', '', '']]
# ['everyone', ['']]
# ['shouted.', ['', '']]
# ['+', []]
# ["Harry's", ['PERSON', '']]
# ['broom', ['']]
# ['jumped', ['']]
# ['into', ['']]
# ['his', ['']]
# ['hand', ['']]
# ['at', ['']]
# ['once,', ['', '']]
# ['but', ['']]
# ['it', ['']]
# ['was', ['']]
# ['one', ['']]
# ['of', ['']]
# ['the', ['']]
# ['few', ['']]
# ['that', ['']]
# ['did.', ['', '']]
# ['Hermione', ['PERSON']]
# ["Granger's", ['PERSON', 'PERSON']]
# ['had', ['']]
# ['simply', ['']]
# ['rolled', ['']]
# ['over', ['']]
# ['on', ['']]
# ['the', ['']]
# ['ground,', ['', '']]
# ['and', ['']]
# ["Neville's", ['PERSON', '']]
# ["hadn't", ['', '']]
# ['moved', ['']]
# ['at', ['']]
# ['all.', ['', '']]
# ['Perhaps', ['']]
# ['brooms,', ['', '']]
# ['like', ['']]
# ['horses,', ['', '']]
# ['could', ['']]
# ['tell', ['']]
# ['when', ['']]
# ['you', ['']]
# ['were', ['']]
# ['afraid,', ['', '']]
# ['thought', ['']]
# ['Harry;', ['PERSON', '']]
# ['there', ['']]
# ['was', ['']]
# ['a', ['']]
# ['quaver', ['']]
# ['in', ['']]
# ["Neville's", ['PERSON', '']]
# ['voice', ['']]
# ['that', ['']]
# ['said', ['']]
# ['only', ['']]
# ['too', ['']]
# ['clearly', ['']]
# ['that', ['']]
# ['he', ['']]
# ['wanted', ['']]
# ['to', ['']]
# ['keep', ['']]
# ['his', ['']]
# ['feet', ['']]
# ['on', ['']]
# ['the', ['']]
# ['ground.', ['', '']]
# ['+', []]
# ['Madam', ['']]
# ['Hooch', ['PERSON']]
# ['then', ['']]
# ['showed', ['']]
# ['them', ['']]
# ['how', ['']]
# ['to', ['']]
# ['mount', ['']]
# ['their', ['']]
# ['brooms', ['']]
# ['without', ['']]
# ['sliding', ['']]
# ['off', ['']]
# ['the', ['']]
# ['end,', ['', '']]
# ['and', ['']]
# ['walked', ['']]
# ['up', ['']]
# ['and', ['']]
# ['down', ['']]
# ['the', ['']]
# ['rows', ['']]
# ['correcting', ['']]
# ['their', ['']]
# ['grips.', ['', '']]
# ['Harry', ['PERSON']]
# ['and', ['']]
# ['Ron', ['PERSON']]
# ['were', ['']]
# ['delighted', ['']]
# ['when', ['']]
# ['she', ['']]
# ['told', ['']]
# ['Malfoy', ['PERSON']]
# ["he'd", ['', '']]
# ['been', ['']]
# ['doing', ['']]
# ['it', ['']]
# ['wrong', ['']]
# ['for', ['']]
# ['years.', ['DATE', '']]
# ['+', []]
# ['"Now,', ['', '', '']]
# ['when', ['']]
# ['I', ['']]
# ['blow', ['']]
# ['my', ['']]
# ['whistle,', ['', '']]
# ['you', ['']]
# ['kick', ['']]
# ['off', ['']]
# ['from', ['']]
# ['the', ['']]
# ['ground,', ['', '']]
# ['hard,"', ['', '', '']]
# ['said', ['']]
# ['Madam', ['']]
# ['Hooch.', ['PERSON', '']]
# ['"Keep', ['', '']]
# ['your', ['']]
# ['brooms', ['']]
# ['steady,', ['', '']]
# ['rise', ['']]
# ['a', ['QUANTITY']]
# ['few', ['QUANTITY']]
# ['feet,', ['QUANTITY', '']]
# ['and', ['']]
# ['then', ['']]
# ['come', ['']]
# ['straight', ['']]
# ['back', ['']]
# ['down', ['']]
# ['by', ['']]
# ['leaning', ['']]
# ['forward', ['']]
# ['slightly.', ['', '']]
# ['On', ['']]
# ['my', ['']]
# ['whistle', ['']]
# ['--', ['']]
# ['three', ['CARDINAL']]
# ['--', ['']]
# ['two', ['CARDINAL']]
# ['--"', ['', '']]
# ['+', []]
# ['But', ['']]
# ['Neville,', ['PERSON', '']]
# ['nervous', ['']]
# ['and', ['']]
# ['jumpy', ['']]
# ['and', ['']]
# ['frightened', ['']]
# ['of', ['']]
# ['being', ['']]
# ['left', ['']]
# ['on', ['']]
# ['the', ['']]
# ['ground,', ['', '']]
# ['pushed', ['']]
# ['off', ['']]
# ['hard', ['']]
# ['before', ['']]
# ['the', ['']]
# ['whistle', ['']]
# ['had', ['']]
# ['touched', ['']]
# ['Madam', ['']]
# ["Hooch's", ['PERSON', '']]
# ['lips.', ['', '']]
# ['+', []]
# ['"Come', ['', '']]
# ['back,', ['', '']]
# ['boy!"', ['', '', '']]
# ['she', ['']]
# ['shouted,', ['', '']]
# ['but', ['']]
# ['Neville', ['PERSON']]
# ['was', ['']]
# ['rising', ['']]
# ['straight', ['']]
# ['up', ['']]
# ['like', ['']]
# ['a', ['']]
# ['cork', ['']]
# ['shot', ['']]
# ['out', ['']]
# ['of', ['']]
# ['a', ['']]
# ['bottle', ['']]
# ['--', ['']]
# ['twelve', ['QUANTITY']]
# ['feet', ['QUANTITY']]
# ['--', ['']]
# ['twenty', ['QUANTITY']]
# ['feet.', ['QUANTITY', '']]
# ['Harry', ['PERSON']]
# ['saw', ['']]
# ['his', ['']]
# ['scared', ['']]
# ['white', ['']]
# ['face', ['']]
# ['look', ['']]
# ['down', ['']]
# ['at', ['']]
# ['the', ['']]
# ['ground', ['']]
# ['falling', ['']]
# ['away,', ['', '']]
# ['saw', ['']]
# ['him', ['']]
# ['gasp,', ['', '']]
# ['slip', ['']]
# ['sideways', ['']]
# ['off', ['']]
# ['the', ['']]
# ['broom', ['']]
# ['and', ['']]
# ['--', ['']]
# ['+', []]
# ['WHAM', ['ORG']]
# ['--', ['']]
# ['a', ['']]
# ['thud', ['']]
# ['and', ['']]
# ['a', ['']]
# ['nasty', ['']]
# ['crack', ['']]
# ['and', ['']]
# ['Neville', ['PERSON']]
# ['lay', ['']]
# ['facedown', ['']]
# ['on', ['']]
# ['the', ['']]
# ['grass', ['']]
# ['in', ['']]
# ['a', ['']]
# ['heap.', ['', '']]
# ['His', ['']]
# ['broomstick', ['']]
# ['was', ['']]
# ['still', ['']]
# ['rising', ['']]
# ['higher', ['']]
# ['and', ['']]
# ['higher,', ['', '']]
# ['and', ['']]
# ['started', ['']]
# ['to', ['']]
# ['drift', ['']]
# ['lazily', ['']]
# ['toward', ['']]
# ['the', ['']]
# ['forbidden', ['']]
# ['forest', ['']]
# ['and', ['']]
# ['out', ['']]
# ['of', ['']]
# ['sight.', ['', '']]
# ['+', []]
# ['Madam', ['']]
# ['Hooch', ['PERSON']]
# ['was', ['']]
# ['bending', ['']]
# ['over', ['']]
# ['Neville,', ['PERSON', '']]
# ['her', ['']]
# ['face', ['']]
# ['as', ['']]
# ['white', ['']]
# ['as', ['']]
# ['his.', ['', '']]
# ['"Broken', ['', '']]
# ['wrist,"', ['', '', '']]
# ['Harry', ['PERSON']]
# ['heard', ['']]
# ['her', ['']]
# ['mutter.', ['', '']]
# ['"Come', ['', '']]
# ['on,', ['', '']]
# ['boy', ['']]
# ['--', ['']]
# ["it's", ['', '']]
# ['all', ['']]
# ['right,', ['', '']]
# ['up', ['']]
# ['you', ['']]
# ['get."', ['', '', '']]
# ['+', []]
# ['She', ['']]
# ['turned', ['']]
# ['to', ['']]
# ['the', ['']]
# ['rest', ['']]
# ['of', ['']]
# ['the', ['']]
# ['class.', ['', '']]
# ['"None', ['', '']]
# ['of', ['']]
# ['you', ['']]
# ['is', ['']]
# ['to', ['']]
# ['move', ['']]
# ['while', ['']]
# ['I', ['']]
# ['take', ['']]
# ['this', ['']]
# ['boy', ['']]
# ['to', ['']]
# ['the', ['']]
# ['hospital', ['']]
# ['wing!', ['', '']]
# ['You', ['']]
# ['leave', ['']]
# ['those', ['']]
# ['brooms', ['']]
# ['where', ['']]
# ['they', ['']]
# ['are', ['']]
# ['or', ['']]
# ["you'll", ['', '']]
# ['be', ['']]
# ['out', ['']]
# ['of', ['']]
# ['Hogwarts', ['PERSON']]
# ['before', ['']]
# ['you', ['']]
# ['can', ['']]
# ['say', ['']]
# ["'Quidditch.'", ['', '', '', '']]
# ['Come', ['']]
# ['on,', ['', '']]
# ['dear."', ['', '', '']]
# ['+', []]
# ['Neville,', ['PERSON', '']]
# ['his', ['']]
# ['face', ['']]
# ['tear-streaked,', ['', '', '', '']]
# ['clutching', ['']]
# ['his', ['']]
# ['wrist,', ['', '']]
# ['hobbled', ['']]
# ['off', ['']]
# ['with', ['']]
# ['Madam', ['']]
# ['Hooch,', ['PERSON', '']]
# ['who', ['']]
# ['had', ['']]
# ['her', ['']]
# ['arm', ['']]
# ['around', ['']]
# ['him.', ['', '']]
# ['+', []]
# ['No', ['']]
# ['sooner', ['']]
# ['were', ['']]
# ['they', ['']]
# ['out', ['']]
# ['of', ['']]
# ['earshot', ['']]
# ['than', ['']]
# ['Malfoy', ['PERSON']]
# ['burst', ['']]
# ['into', ['']]
# ['laughter.', ['', '']]
# ['+', []]
# ['"Did', ['', '']]
# ['you', ['']]
# ['see', ['']]
# ['his', ['']]
# ['face,', ['', '']]
# ['the', ['']]
# ['great', ['']]
# ['lump?"', ['', '', '']]
# ['+', []]
# ['The', ['']]
# ['other', ['']]
# ['Slytherins', ['NORP']]
# ['joined', ['']]
# ['in.', ['', '']]
# ['+', []]
# ['"Shut', ['', '']]
# ['up,', ['', '']]
# ['Malfoy,"', ['PERSON', '', '']]
# ['snapped', ['']]
# ['Parvati', ['PERSON']]
# ['Patil.', ['PERSON', '']]
# ['+', []]
# ['"Ooh,', ['', '', '']]
# ['sticking', ['']]
# ['up', ['']]
# ['for', ['']]
# ['Longbottom?"', ['PERSON', '', '']]
# ['said', ['']]
# ['Pansy', ['']]
# ['Parkinson,', ['', '']]
# ['a', ['']]
# ['hard-faced', ['', '', '']]
# ['Slytherin', ['']]
# ['girl.', ['', '']]
# ['"Never', ['', '']]
# ['thought', ['']]
# ["you'd", ['', '']]
# ['like', ['']]
# ['fat', ['']]
# ['little', ['']]
# ['crybabies,', ['', '']]
# ['Parvati."', ['PERSON', '', '']]
# ['+', []]
# ['"Look!"', ['', '', '', '']]
# ['said', ['']]
# ['Malfoy,', ['PERSON', '']]
# ['darting', ['']]
# ['forward', ['']]
# ['and', ['']]
# ['snatching', ['']]
# ['something', ['']]
# ['out', ['']]
# ['of', ['']]
# ['the', ['']]
# ['grass.', ['', '']]
# ['"It\'s', ['', '', '']]
# ['that', ['']]
# ['stupid', ['']]
# ['thing', ['']]
# ["Longbottom's", ['PERSON', '']]
# ['gran', ['']]
# ['sent', ['']]
# ['him."', ['', '', '']]
# ['+', []]
# ['The', ['']]
# ['Remembrall', ['PERSON']]
# ['glittered', ['']]
# ['in', ['']]
# ['the', ['']]
# ['sun', ['']]
# ['as', ['']]
# ['he', ['']]
# ['held', ['']]
# ['it', ['']]
# ['up.', ['', '']]
# ['+', []]
# ['"Give', ['', '']]
# ['that', ['']]
# ['here,', ['', '']]
# ['Malfoy,"', ['PERSON', '', '']]
# ['said', ['']]
# ['Harry', ['PERSON']]
# ['quietly.', ['', '']]
# ['Everyone', ['']]
# ['stopped', ['']]
# ['talking', ['']]
# ['to', ['']]
# ['watch.', ['', '']]
# ['+', []]
# ['Malfoy', ['PERSON']]
# ['smiled', ['']]
# ['nastily.', ['', '']]
# ['"I', ['', '']]
# ['think', ['']]
# ["I'll", ['', '']]
# ['leave', ['']]
# ['it', ['']]
# ['somewhere', ['']]
# ['for', ['']]
# ['Longbottom', ['PERSON']]
# ['to', ['']]
# ['find', ['']]
# ['--', ['']]
# ['how', ['']]
# ['about', ['']]
# ['--', ['']]
# ['up', ['']]
# ['a', ['']]
# ['tree?"', ['', '', '']]
# ['+', []]
# ['"Give', ['', '']]
# ['it', ['']]
# ['here!"', ['', '', '']]
# ['Harry', ['PERSON']]
# ['yelled,', ['', '']]
# ['but', ['']]
# ['Malfoy', ['PERSON']]
# ['had', ['']]
# ['leapt', ['']]
# ['onto', ['']]
# ['his', ['']]
# ['broomstick', ['']]
# ['and', ['']]
# ['taken', ['']]
# ['off.', ['', '']]
# ['He', ['']]
# ["hadn't", ['', '']]
# ['been', ['']]
# ['lying,', ['', '']]
# ['he', ['']]
# ['could', ['']]
# ['fly', ['']]
# ['well.', ['', '']]
# ['Hovering', ['']]
# ['level', ['']]
# ['with', ['']]
# ['the', ['']]
# ['topmost', ['']]
# ['branches', ['']]
# ['of', ['']]
# ['an', ['']]
# ['oak', ['']]
# ['he', ['']]
# ['called,', ['', '']]
# ['"Come', ['', '']]
# ['and', ['']]
# ['get', ['']]
# ['it,', ['', '']]
# ['Potter!"', ['', '', '']]
# ['+', []]
# ['Harry', ['PERSON']]
# ['grabbed', ['']]
# ['his', ['']]
# ['broom.', ['', '']]
# ['+', []]
# ['"No!"', ['', '', '', '']]
# ['shouted', ['']]
# ['Hermione', ['PERSON']]
# ['Granger.', ['PERSON', '']]
# ['"Madam', ['', '']]
# ['Hooch', ['PERSON']]
# ['told', ['']]
# ['us', ['']]
# ['not', ['']]
# ['to', ['']]
# ['move', ['']]
# ['--', ['']]
# ["you'll", ['', '']]
# ['get', ['']]
# ['us', ['']]
# ['all', ['']]
# ['into', ['']]
# ['trouble."', ['', '', '']]
# ['+', []]
# ['Harry', ['PERSON']]
# ['ignored', ['']]
# ['her.', ['', '']]
# ['Blood', ['']]
# ['was', ['']]
# ['pounding', ['']]
# ['in', ['']]
# ['his', ['']]
# ['ears.', ['', '']]
# ['He', ['']]
# ['mounted', ['']]
# ['the', ['']]
# ['broom', ['']]
# ['and', ['']]
# ['kicked', ['']]
# ['hard', ['']]
# ['against', ['']]
# ['the', ['']]
# ['ground', ['']]
# ['and', ['']]
# ['up,', ['', '']]
# ['up', ['']]
# ['he', ['']]
# ['soared;', ['', '']]
# ['air', ['']]
# ['rushed', ['']]
# ['through', ['']]
# ['his', ['']]
# ['hair,', ['', '']]
# ['and', ['']]
# ['his', ['']]
# ['robes', ['']]
# ['whipped', ['']]
# ['out', ['']]
# ['behind', ['']]
# ['him', ['']]
# ['--', ['']]
# ['and', ['']]
# ['in', ['']]
# ['a', ['']]
# ['rush', ['']]
# ['of', ['']]
# ['fierce', ['']]
# ['joy', ['']]
# ['he', ['']]
# ['realized', ['']]
# ["he'd", ['', '']]
# ['found', ['']]
# ['something', ['']]
# ['he', ['']]
# ['could', ['']]
# ['do', ['']]
# ['without', ['']]
# ['being', ['']]
# ['taught', ['']]
# ['--', ['']]
# ['this', ['']]
# ['was', ['']]
# ['easy,', ['', '']]
# ['this', ['']]
# ['was', ['']]
# ['wonderful.', ['', '']]
# ['He', ['']]
# ['pulled', ['']]
# ['his', ['']]
# ['broomstick', ['']]
# ['up', ['']]
# ['a', ['']]
# ['little', ['']]
# ['to', ['']]
# ['take', ['']]
# ['it', ['']]
# ['even', ['']]
# ['higher,', ['', '']]
# ['and', ['']]
# ['heard', ['']]
# ['screams', ['']]
# ['and', ['']]
# ['gasps', ['']]
# ['of', ['']]
# ['girls', ['']]
# ['back', ['']]
# ['on', ['']]
# ['the', ['']]
# ['ground', ['']]
# ['and', ['']]
# ['an', ['']]
# ['admiring', ['']]
# ['whoop', ['']]
# ['from', ['']]
# ['Ron.', ['PERSON', '']]
# ['+', []]
# ['He', ['']]
# ['turned', ['']]
# ['his', ['']]
# ['broomstick', ['']]
# ['sharply', ['']]
# ['to', ['']]
# ['face', ['']]
# ['Malfoy', ['PERSON']]
# ['in', ['']]
# ['midair.', ['', '']]
# ['+', []]
# ['Malfoy', ['PERSON']]
# ['looked', ['']]
# ['stunned.', ['', '']]
# ['"Give', ['', '']]
# ['it', ['']]
# ['here,"', ['', '', '']]
# ['Harry', ['PERSON']]
# ['called,', ['', '']]
# ['"or', ['', '']]
# ["I'll", ['', '']]
# ['knock', ['']]
# ['you', ['']]
# ['off', ['']]
# ['that', ['']]
# ['broom!"', ['', '', '']]
# ['+', []]
# ['"Oh,', ['', '', '']]
# ['yeah?"', ['', '', '']]
# ['said', ['']]
# ['Malfoy,', ['PERSON', '']]
# ['trying', ['']]
# ['to', ['']]
# ['sneer,', ['', '']]
# ['but', ['']]
# ['looking', ['']]
# ['worried.', ['', '']]
# ['+', []]
# ['Harry', ['PERSON']]
# ['knew,', ['', '']]
# ['somehow,', ['', '']]
# ['what', ['']]
# ['to', ['']]
# ['do.', ['', '']]
# ['He', ['']]
# ['leaned', ['']]
# ['forward', ['']]
# ['and', ['']]
# ['grasped', ['']]
# ['the', ['']]
# ['broom', ['']]
# ['tightly', ['']]
# ['in', ['']]
# ['both', ['']]
# ['hands,', ['', '']]
# ['and', ['']]
# ['it', ['']]
# ['shot', ['']]
# ['toward', ['']]
# ['Malfoy', ['PERSON']]
# ['like', ['']]
# ['a', ['']]
# ['javelin.', ['', '']]
# ['Malfoy', ['']]
# ['only', ['']]
# ['just', ['']]
# ['got', ['']]
# ['out', ['']]
# ['of', ['']]
# ['the', ['']]
# ['way', ['']]
# ['in', ['']]
# ['time;', ['', '']]
# ['Harry', ['PERSON']]
# ['made', ['']]
# ['a', ['']]
# ['sharp', ['']]
# ['about-face', ['', '', '']]
# ['and', ['']]
# ['held', ['']]
# ['the', ['']]
# ['broom', ['']]
# ['steady.', ['', '']]
# ['A', ['']]
# ['few', ['']]
# ['people', ['']]
# ['below', ['']]
# ['were', ['']]
# ['clapping.', ['', '']]
# ['+', []]
# ['"No', ['', '']]
# ['Crabbe', ['']]
# ['and', ['']]
# ['Goyle', ['PERSON']]
# ['up', ['']]
# ['here', ['']]
# ['to', ['']]
# ['save', ['']]
# ['your', ['']]
# ['neck,', ['', '']]
# ['Malfoy,"', ['PERSON', '', '']]
# ['Harry', ['PERSON']]
# ['called.', ['', '']]
# ['+', []]
# ['The', ['']]
# ['same', ['']]
# ['thought', ['']]
# ['seemed', ['']]
# ['to', ['']]
# ['have', ['']]
# ['struck', ['']]
# ['Malfoy.', ['PERSON', '']]
# ['+', []]
# ['"Catch', ['', '']]
# ['it', ['']]
# ['if', ['']]
# ['you', ['']]
# ['can,', ['', '']]
# ['then!"', ['', '', '']]
# ['he', ['']]
# ['shouted,', ['', '']]
# ['and', ['']]
# ['he', ['']]
# ['threw', ['']]
# ['the', ['']]
# ['glass', ['']]
# ['ball', ['']]
# ['high', ['']]
# ['into', ['']]
# ['the', ['']]
# ['air', ['']]
# ['and', ['']]
# ['streaked', ['']]
# ['back', ['']]
# ['toward', ['']]
# ['the', ['']]
# ['ground.', ['', '']]
# ['+', []]
# ['Harry', ['PERSON']]
# ['saw,', ['', '']]
# ['as', ['']]
# ['though', ['']]
# ['in', ['']]
# ['slow', ['']]
# ['motion,', ['', '']]
# ['the', ['']]
# ['ball', ['']]
# ['rise', ['']]
# ['up', ['']]
# ['in', ['']]
# ['the', ['']]
# ['air', ['']]
# ['and', ['']]
# ['then', ['']]
# ['start', ['']]
# ['to', ['']]
# ['fall.', ['', '']]
# ['He', ['']]
# ['leaned', ['']]
# ['forward', ['']]
# ['and', ['']]
# ['pointed', ['']]
# ['his', ['']]
# ['broom', ['']]
# ['handle', ['']]
# ['down', ['']]
# ['--', ['']]
# ['next', ['']]
# ['second', ['']]
# ['he', ['']]
# ['was', ['']]
# ['gathering', ['']]
# ['speed', ['']]
# ['in', ['']]
# ['a', ['']]
# ['steep', ['']]
# ['dive,', ['', '']]
# ['racing', ['']]
# ['the', ['']]
# ['ball', ['']]
# ['--', ['']]
# ['wind', ['']]
# ['whistled', ['']]
# ['in', ['']]
# ['his', ['']]
# ['ears,', ['', '']]
# ['mingled', ['']]
# ['with', ['']]
# ['the', ['']]
# ['screams', ['']]
# ['of', ['']]
# ['people', ['']]
# ['watching', ['']]
# ['--', ['']]
# ['he', ['']]
# ['stretched', ['']]
# ['out', ['']]
# ['his', ['']]
# ['hand', ['']]
# ['--', ['']]
# ['a', ['']]
# ['foot', ['']]
# ['from', ['']]
# ['the', ['']]
# ['ground', ['']]
# ['he', ['']]
# ['caught', ['']]
# ['it,', ['', '']]
# ['just', ['']]
# ['in', ['']]
# ['time', ['']]
# ['to', ['']]
# ['pull', ['']]
# ['his', ['']]
# ['broom', ['']]
# ['straight,', ['', '']]
# ['and', ['']]
# ['he', ['']]
# ['toppled', ['']]
# ['gently', ['']]
# ['onto', ['']]
# ['the', ['']]
# ['grass', ['']]
# ['with', ['']]
# ['the', ['']]
# ['Remembrall', ['PERSON']]
# ['clutched', ['']]
# ['safely', ['']]
# ['in', ['']]
# ['his', ['']]
# ['fist.', ['', '']]
# ['+', []]
# ['"HARRY', ['', 'WORK_OF_ART']]
# ['POTTER!"', ['WORK_OF_ART', 'WORK_OF_ART', '']]
# ['+', []]
# ['His', ['']]
# ['heart', ['']]
# ['sank', ['']]
# ['faster', ['']]
# ['than', ['']]
# ["he'd", ['', '']]
# ['just', ['']]
# ['dived.', ['', '']]
# ['Professor', ['']]
# ['McGonagall', ['PERSON']]
# ['was', ['']]
# ['running', ['']]
# ['toward', ['']]
# ['them.', ['', '']]
# ['He', ['']]
# ['got', ['']]
# ['to', ['']]
# ['his', ['']]
# ['feet,', ['', '']]
# ['trembling.', ['', '']]
# ['+', []]
# ['"Never', ['', '']]
# ['--', ['']]
# ['in', ['']]
# ['all', ['']]
# ['my', ['']]
# ['time', ['']]
# ['at', ['']]
# ['Hogwarts', ['']]
# ['--"', ['', '']]
# ['Professor', ['']]
# ['McGonagall', ['PERSON']]
# ['was', ['']]
# ['almost', ['']]
# ['speechless', ['']]
# ['with', ['']]
# ['shock,', ['', '']]
# ['and', ['']]
# ['her', ['']]
# ['glasses', ['']]
# ['flashed', ['']]
# ['furiously,', ['', '']]
# ['"--', ['', '']]
# ['how', ['']]
# ['dare', ['']]
# ['you', ['']]
# ['--', ['']]
# ['might', ['']]
# ['have', ['']]
# ['broken', ['']]
# ['your', ['']]
# ['neck', ['']]
# ['--"', ['', '']]
# ['+', []]
# ['"It', ['', '']]
# ["wasn't", ['', '']]
# ['his', ['']]
# ['fault,', ['', '']]
# ['Professor', ['']]
# ['--"', ['', '']]
# ['+', []]
# ['"Be', ['', '']]
# ['quiet,', ['', '']]
# ['Miss', ['']]
# ['Patil', ['PERSON']]
# ['--"', ['', '']]
# ['+', []]
# ['"But', ['', '']]
# ['Malfoy', ['']]
# ['--"', ['', '']]
# ['"That\'s', ['', '', '']]
# ['enough,', ['', '']]
# ['Mr.', ['']]
# ['Weasley.', ['PERSON', '']]
# ['Potter,', ['', '']]
# ['follow', ['']]
# ['me,', ['', '']]
# ['now."', ['', '', '']]
# ['+', []]
# ['Harry', ['PERSON']]
# ['caught', ['']]
# ['sight', ['']]
# ['of', ['']]
# ['Malfoy,', ['', '']]
# ['Crabbe,', ['PERSON', '']]
# ['and', ['']]
# ["Goyle's", ['PERSON', '']]
# ['triumphant', ['']]
# ['faces', ['']]
# ['as', ['']]
# ['he', ['']]
# ['left,', ['', '']]
# ['walking', ['']]
# ['numbly', ['']]
# ['in', ['']]
# ['Professor', ['']]
# ["McGonagall's", ['PERSON', '']]
# ['wake', ['']]
# ['as', ['']]
# ['she', ['']]
# ['strode', ['']]
# ['toward', ['']]
# ['the', ['']]
# ['castle.', ['', '']]
# ['He', ['']]
# ['was', ['']]
# ['going', ['']]
# ['to', ['']]
# ['be', ['']]
# ['expelled,', ['', '']]
# ['he', ['']]
# ['just', ['']]
# ['knew', ['']]
# ['it.', ['', '']]
# ['He', ['']]
# ['wanted', ['']]
# ['to', ['']]
# ['say', ['']]
# ['something', ['']]
# ['to', ['']]
# ['defend', ['']]
# ['himself,', ['', '']]
# ['but', ['']]
# ['there', ['']]
# ['seemed', ['']]
# ['to', ['']]
# ['be', ['']]
# ['something', ['']]
# ['wrong', ['']]
# ['with', ['']]
# ['his', ['']]
# ['voice.', ['', '']]
# ['Professor', ['']]
# ['McGonagall', ['PERSON']]
# ['was', ['']]
# ['sweeping', ['']]
# ['along', ['']]
# ['without', ['']]
# ['even', ['']]
# ['looking', ['']]
# ['at', ['']]
# ['him;', ['', '']]
# ['he', ['']]
# ['had', ['']]
# ['to', ['']]
# ['jog', ['']]
# ['to', ['']]
# ['keep', ['']]
# ['up.', ['', '']]
# ['Now', ['']]
# ["he'd", ['', '']]
# ['done', ['']]
# ['it.', ['', '']]
# ['He', ['']]
# ["hadn't", ['', '']]
# ['even', ['']]
# ['lasted', ['']]
# ['two', ['DATE']]
# ['weeks.', ['DATE', '']]
# ["He'd", ['', '']]
# ['be', ['']]
# ['packing', ['']]
# ['his', ['']]
# ['bags', ['']]
# ['in', ['']]
# ['ten', ['TIME']]
# ['minutes.', ['TIME', '']]
# ['What', ['']]
# ['would', ['']]
# ['the', ['']]
# ['Dursleys', ['PERSON']]
# ['say', ['']]
# ['when', ['']]
# ['he', ['']]
# ['turned', ['']]
# ['up', ['']]
# ['on', ['']]
# ['the', ['']]
# ['doorstep?', ['', '']]
# ['+', []]
# ['Up', ['']]
# ['the', ['']]
# ['front', ['']]
# ['steps,', ['', '']]
# ['up', ['']]
# ['the', ['']]
# ['marble', ['']]
# ['staircase', ['']]
# ['inside,', ['', '']]
# ['and', ['']]
# ['still', ['']]
# ['Professor', ['']]
# ['McGonagall', ['PERSON']]
# ["didn't", ['', '']]
# ['say', ['']]
# ['a', ['']]
# ['word', ['']]
# ['to', ['']]
# ['him.', ['', '']]
# ['She', ['']]
# ['wrenched', ['']]
# ['open', ['']]
# ['doors', ['']]
# ['and', ['']]
# ['marched', ['']]
# ['along', ['']]
# ['corridors', ['']]
# ['with', ['']]
# ['Harry', ['PERSON']]
# ['trotting', ['']]
# ['miserably', ['']]
# ['behind', ['']]
# ['her.', ['', '']]
# ['Maybe', ['']]
# ['she', ['']]
# ['was', ['']]
# ['taking', ['']]
# ['him', ['']]
# ['to', ['']]
# ['Dumbledore.', ['', '']]
# ['He', ['']]
# ['thought', ['']]
# ['of', ['']]
# ['Hagrid,', ['', '']]
# ['expelled', ['']]
# ['but', ['']]
# ['allowed', ['']]
# ['to', ['']]
# ['stay', ['']]
# ['on', ['']]
# ['as', ['']]
# ['gamekeeper.', ['', '']]
# ['Perhaps', ['']]
# ['he', ['']]
# ['could', ['']]
# ['be', ['']]
# ["Hagrid's", ['', '']]
# ['assistant.', ['', '']]
# ['His', ['']]
# ['stomach', ['']]
# ['twisted', ['']]
# ['as', ['']]
# ['he', ['']]
# ['imagined', ['']]
# ['it,', ['', '']]
# ['watching', ['']]
# ['Ron', ['PERSON']]
# ['and', ['']]
# ['the', ['']]
# ['others', ['']]
# ['becoming', ['']]
# ['wizards', ['']]
# ['while', ['']]
# ['he', ['']]
# ['stumped', ['']]
# ['around', ['']]
# ['the', ['']]
# ['grounds', ['']]
# ['carrying', ['']]
# ["Hagrid's", ['', '']]
# ['bag.', ['', '']]
# ['+', []]
# ['Professor', ['']]
# ['McGonagall', ['PERSON']]
# ['stopped', ['']]
# ['outside', ['']]
# ['a', ['']]
# ['classroom.', ['', '']]
# ['She', ['']]
# ['opened', ['']]
# ['the', ['']]
# ['door', ['']]
# ['and', ['']]
# ['poked', ['']]
# ['her', ['']]
# ['head', ['']]
# ['inside.', ['', '']]
# ['+', []]
# ['"Excuse', ['', '']]
# ['me,', ['', '']]
# ['Professor', ['']]
# ['Flitwick,', ['PERSON', '']]
# ['could', ['']]
# ['I', ['']]
# ['borrow', ['']]
# ['Wood', ['']]
# ['for', ['']]
# ['a', ['']]
# ['moment?"', ['', '', '']]
# ['+', []]
# ['Wood?', ['', '']]
# ['thought', ['']]
# ['Harry,', ['PERSON', '']]
# ['bewildered;', ['', '']]
# ['was', ['']]
# ['Wood', ['ORG']]
# ['a', ['']]
# ['cane', ['']]
# ['she', ['']]
# ['was', ['']]
# ['going', ['']]
# ['to', ['']]
# ['use', ['']]
# ['on', ['']]
# ['him?', ['', '']]
# ['But', ['']]
# ['Wood', ['']]
# ['turned', ['']]
# ['out', ['']]
# ['to', ['']]
# ['be', ['']]
# ['a', ['']]
# ['person,', ['', '']]
# ['a', ['']]
# ['burly', ['']]
# ['fifth-year', ['DATE', 'DATE', 'DATE']]
# ['boy', ['']]
# ['who', ['']]
# ['came', ['']]
# ['out', ['']]
# ['of', ['']]
# ["Flitwick's", ['ORG', '']]
# ['class', ['']]
# ['looking', ['']]
# ['confused.', ['', '']]
# ['+', []]
# ['"Follow', ['', '']]
# ['me,', ['', '']]
# ['you', ['']]
# ['two,"', ['CARDINAL', '', '']]
# ['said', ['']]
# ['Professor', ['']]
# ['McGonagall,', ['PERSON', '']]
# ['and', ['']]
# ['they', ['']]
# ['marched', ['']]
# ['on', ['']]
# ['up', ['']]
# ['the', ['']]
# ['corridor,', ['', '']]
# ['Wood', ['']]
# ['looking', ['']]
# ['curiously', ['']]
# ['at', ['']]
# ['Harry.', ['PERSON', '']]
# ['+', []]
# ['"In', ['', '']]
# ['here."', ['', '', '']]
# ['+', []]
# ['Professor', ['']]
# ['McGonagall', ['PERSON']]
# ['pointed', ['']]
# ['them', ['']]
# ['into', ['']]
# ['a', ['']]
# ['classroom', ['']]
# ['that', ['']]
# ['was', ['']]
# ['empty', ['']]
# ['except', ['']]
# ['for', ['']]
# ['Peeves,', ['', '']]
# ['who', ['']]
# ['was', ['']]
# ['busy', ['']]
# ['writing', ['']]
# ['rude', ['']]
# ['words', ['']]
# ['on', ['']]
# ['the', ['']]
# ['blackboard.', ['', '']]
# ['+', []]
# ['"Out,', ['', '', '']]
# ['Peeves!"', ['', '', '']]
# ['she', ['']]
# ['barked.', ['', '']]
# ['Peeves', ['']]
# ['threw', ['']]
# ['the', ['']]
# ['chalk', ['']]
# ['into', ['']]
# ['a', ['']]
# ['bin,', ['', '']]
# ['which', ['']]
# ['clanged', ['']]
# ['loudly,', ['', '']]
# ['and', ['']]
# ['he', ['']]
# ['swooped', ['']]
# ['out', ['']]
# ['cursing.', ['', '']]
# ['Professor', ['']]
# ['McGonagall', ['PERSON']]
# ['slammed', ['']]
# ['the', ['']]
# ['door', ['']]
# ['behind', ['']]
# ['him', ['']]
# ['and', ['']]
# ['turned', ['']]
# ['to', ['']]
# ['face', ['']]
# ['the', ['']]
# ['two', ['CARDINAL']]
# ['boys.', ['', '']]
# ['+', []]
# ['"Potter,', ['', '', '']]
# ['this', ['']]
# ['is', ['']]
# ['Oliver', ['PERSON']]
# ['Wood.', ['PERSON', '']]
# ['Wood', ['']]
# ['--', ['']]
# ["I've", ['', '']]
# ['found', ['']]
# ['you', ['']]
# ['a', ['']]
# ['Seeker."', ['', '', '']]
# ['+', []]
# ["Wood's", ['ORG', '']]
# ['expression', ['']]
# ['changed', ['']]
# ['from', ['']]
# ['puzzlement', ['']]
# ['to', ['']]
# ['delight.', ['', '']]
# ['+', []]
# ['"Are', ['', '']]
# ['you', ['']]
# ['serious,', ['', '']]
# ['Professor?"', ['', '', '']]
# ['+', []]
# ['"Absolutely,"', ['', '', '', '']]
# ['said', ['']]
# ['Professor', ['']]
# ['McGonagall', ['PERSON']]
# ['crisply.', ['', '']]
# ['"The', ['', '']]
# ["boy's", ['', '']]
# ['a', ['']]
# ['natural.', ['', '']]
# ["I've", ['', '']]
# ['never', ['']]
# ['seen', ['']]
# ['anything', ['']]
# ['like', ['']]
# ['it.', ['', '']]
# ['Was', ['']]
# ['that', ['']]
# ['your', ['']]
# ['first', ['ORDINAL']]
# ['time', ['']]
# ['on', ['']]
# ['a', ['']]
# ['broomstick,', ['', '']]
# ['Potter?"', ['', '', '']]
# ['+', []]
# ['Harry', ['PERSON']]
# ['nodded', ['']]
# ['silently.', ['', '']]
# ['He', ['']]
# ["didn't", ['', '']]
# ['have', ['']]
# ['a', ['']]
# ['clue', ['']]
# ['what', ['']]
# ['was', ['']]
# ['going', ['']]
# ['on,', ['', '']]
# ['but', ['']]
# ['he', ['']]
# ["didn't", ['', '']]
# ['seem', ['']]
# ['to', ['']]
# ['be', ['']]
# ['being', ['']]
# ['expelled,', ['', '']]
# ['and', ['']]
# ['some', ['']]
# ['of', ['']]
# ['the', ['']]
# ['feeling', ['']]
# ['started', ['']]
# ['coming', ['']]
# ['back', ['']]
# ['to', ['']]
# ['his', ['']]
# ['legs.', ['', '']]
# ['+', []]
# ['"He', ['', '']]
# ['caught', ['']]
# ['that', ['']]
# ['thing', ['']]
# ['in', ['']]
# ['his', ['']]
# ['hand', ['']]
# ['after', ['']]
# ['a', ['']]
# ['fifty-foot', ['QUANTITY', 'QUANTITY', 'QUANTITY']]
# ['dive,"', ['', '', '']]
# ['Professor', ['']]
# ['McGonagall', ['PERSON']]
# ['told', ['']]
# ['Wood.', ['ORG', '']]
# ['"Didn\'t', ['', '', '']]
# ['even', ['']]
# ['scratch', ['']]
# ['himself.', ['', '']]
# ['Charlie', ['PERSON']]
# ['Weasley', ['PERSON']]
# ["couldn't", ['', '']]
# ['have', ['']]
# ['done', ['']]
# ['it."', ['', '', '']]
# ['+', []]
# ['Wood', ['']]
# ['was', ['']]
# ['now', ['']]
# ['looking', ['']]
# ['as', ['']]
# ['though', ['']]
# ['all', ['']]
# ['his', ['']]
# ['dreams', ['']]
# ['had', ['']]
# ['come', ['']]
# ['true', ['']]
# ['at', ['']]
# ['once.', ['', '']]
# ['+', []]
# ['"Ever', ['', '']]
# ['seen', ['']]
# ['a', ['']]
# ['game', ['']]
# ['of', ['']]
# ['Quidditch,', ['ORG', 'ORG']]
# ['Potter?"', ['ORG', '', '']]
# ['he', ['']]
# ['asked', ['']]
# ['excitedly.', ['', '']]
# ['+', []]
# ['"Wood\'s', ['', '', '']]
# ['captain', ['']]
# ['of', ['']]
# ['the', ['']]
# ['Gryffindor', ['']]
# ['team,"', ['', '', '']]
# ['Professor', ['']]
# ['McGonagall', ['']]
# ['explained.', ['', '']]
# ['+', []]
# ['"He\'s', ['', '', '']]
# ['just', ['']]
# ['the', ['']]
# ['build', ['']]
# ['for', ['']]
# ['a', ['']]
# ['Seeker,', ['', '']]
# ['too,"', ['', '', '']]
# ['said', ['']]
# ['Wood,', ['ORG', '']]
# ['now', ['']]
# ['walking', ['']]
# ['around', ['']]
# ['Harry', ['PERSON']]
# ['and', ['']]
# ['staring', ['']]
# ['at', ['']]
# ['him.', ['', '']]
# ['"Light', ['', '']]
# ['--', ['']]
# ['speedy', ['']]
# ['--', ['']]
# ["we'll", ['', '']]
# ['have', ['']]
# ['to', ['']]
# ['get', ['']]
# ['him', ['']]
# ['a', ['']]
# ['decent', ['']]
# ['broom,', ['', '']]
# ['Professor', ['']]
# ['--', ['']]
# ['a', ['']]
# ['Nimbus', ['EVENT']]
# ['Two', ['EVENT']]
# ['Thousand', ['EVENT']]
# ['or', ['']]
# ['a', ['']]
# ['Cleansweep', ['ORG']]
# ['Seven,', ['CARDINAL', '']]
# ["I'd", ['', '']]
# ['say."', ['', '', '']]
# ['+', []]
# ['"I', ['', '']]
# ['shall', ['']]
# ['speak', ['']]
# ['to', ['']]
# ['Professor', ['']]
# ['Dumbledore', ['']]
# ['and', ['']]
# ['see', ['']]
# ['if', ['']]
# ['we', ['']]
# ["can't", ['', '']]
# ['bend', ['']]
# ['the', ['']]
# ['first-year', ['DATE', 'DATE', 'DATE']]
# ['rule.', ['', '']]
# ['Heaven', ['']]
# ['knows,', ['', '']]
# ['we', ['']]
# ['need', ['']]
# ['a', ['']]
# ['better', ['']]
# ['team', ['']]
# ['than', ['']]
# ['last', ['DATE']]
# ['year.', ['DATE', '']]
# ['Flattened', ['']]
# ['in', ['']]
# ['that', ['']]
# ['last', ['']]
# ['match', ['']]
# ['by', ['']]
# ['Slytherin,', ['', '']]
# ['I', ['']]
# ["couldn't", ['', '']]
# ['look', ['']]
# ['Severus', ['PERSON']]
# ['Snape', ['PERSON']]
# ['in', ['']]
# ['the', ['']]
# ['face', ['']]
# ['for', ['']]
# ['weeks.', ['DATE', '']]
# ['..."', ['', '']]
# ['+', []]
# ['Professor', ['']]
# ['McGonagall', ['PERSON']]
# ['peered', ['']]
# ['sternly', ['']]
# ['over', ['']]
# ['her', ['']]
# ['glasses', ['']]
# ['at', ['']]
# ['Harry.', ['PERSON', '']]
# ['+', []]
# ['"I', ['', '']]
# ['want', ['']]
# ['to', ['']]
# ['hear', ['']]
# ["you're", ['', '']]
# ['training', ['']]
# ['hard,', ['', '']]
# ['Potter,', ['', '']]
# ['or', ['']]
# ['I', ['']]
# ['may', ['']]
# ['change', ['']]
# ['my', ['']]
# ['mind', ['']]
# ['about', ['']]
# ['punishing', ['']]
# ['you."', ['', '', '']]
# ['+', []]
# ['Then', ['']]
# ['she', ['']]
# ['suddenly', ['']]
# ['smiled.', ['', '']]
# ['+', []]
# ['"Your', ['', '']]
# ['father', ['']]
# ['would', ['']]
# ['have', ['']]
# ['been', ['']]
# ['proud,"', ['', '', '']]
# ['she', ['']]
# ['said.', ['', '']]
# ['"He', ['', '']]
# ['was', ['']]
# ['an', ['']]
# ['excellent', ['']]
# ['Quidditch', ['ORG']]
# ['player', ['']]
# ['himself."', ['', '', '']]
# ['+', []]
# ['+', []]
# ['"You\'re', ['', '', '']]
# ['joking."', ['', '', '']]
# ['+', []]
# ['It', ['']]
# ['was', ['']]
# ['dinnertime.', ['', '']]
# ['Harry', ['PERSON']]
# ['had', ['']]
# ['just', ['']]
# ['finished', ['']]
# ['telling', ['']]
# ['Ron', ['PERSON']]
# ['what', ['']]
# ['had', ['']]
# ['happened', ['']]
# ['when', ['']]
# ["he'd", ['', '']]
# ['left', ['']]
# ['the', ['']]
# ['grounds', ['']]
# ['with', ['']]
# ['Professor', ['']]
# ['McGonagall.', ['PERSON', '']]
# ['Ron', ['PERSON']]
# ['had', ['']]
# ['a', ['']]
# ['piece', ['']]
# ['of', ['']]
# ['steak', ['']]
# ['and', ['']]
# ['kidney', ['']]
# ['pie', ['']]
# ['halfway', ['']]
# ['to', ['']]
# ['his', ['']]
# ['mouth,', ['', '']]
# ['but', ['']]
# ["he'd", ['', '']]
# ['forgotten', ['']]
# ['all', ['']]
# ['about', ['']]
# ['it.', ['', '']]
# ['+', []]
# ['"Seeker?"', ['', 'PERSON', '', '']]
# ['he', ['']]
# ['said.', ['', '']]
# ['"But', ['', '']]
# ['first', ['DATE']]
# ['years', ['DATE']]
# ['never', ['']]
# ['--', ['']]
# ['you', ['']]
# ['must', ['']]
# ['be', ['']]
# ['the', ['']]
# ['youngest', ['']]
# ['House', ['ORG']]
# ['player', ['']]
# ['in', ['']]
# ['about', ['']]
# ['--"', ['', '']]
# ['+', []]
# ['"--', ['', '']]
# ['a', ['DATE']]
# ['century,"', ['DATE', '', '']]
# ['said', ['']]
# ['Harry,', ['PERSON', '']]
# ['shoveling', ['']]
# ['pie', ['']]
# ['into', ['']]
# ['his', ['']]
# ['mouth.', ['', '']]
# ['He', ['']]
# ['felt', ['']]
# ['particularly', ['']]
# ['hungry', ['']]
# ['after', ['']]
# ['the', ['']]
# ['excitement', ['']]
# ['of', ['']]
# ['the', ['']]
# ['afternoon.', ['', '']]
# ['"Wood', ['', 'PERSON']]
# ['told', ['']]
# ['me."', ['', '', '']]
# ['+', []]
# ['Ron', ['PERSON']]
# ['was', ['']]
# ['so', ['']]
# ['amazed,', ['', '']]
# ['so', ['']]
# ['impressed,', ['', '']]
# ['he', ['']]
# ['just', ['']]
# ['sat', ['']]
# ['and', ['']]
# ['gaped', ['']]
# ['at', ['']]
# ['Harry.', ['PERSON', '']]
# ['+', []]
# ['"I', ['', '']]
# ['start', ['']]
# ['training', ['']]
# ['next', ['DATE']]
# ['week,"', ['DATE', '', '']]
# ['said', ['']]
# ['Harry.', ['PERSON', '']]
# ['"Only', ['', '']]
# ["don't", ['', '']]
# ['tell', ['']]
# ['anyone,', ['', '']]
# ['Wood', ['ORG']]
# ['wants', ['']]
# ['to', ['']]
# ['keep', ['']]
# ['it', ['']]
# ['a', ['']]
# ['secret."', ['', '', '']]
# ['+', []]
# ['Fred', ['PERSON']]
# ['and', ['']]
# ['George', ['PERSON']]
# ['Weasley', ['PERSON']]
# ['now', ['']]
# ['came', ['']]
# ['into', ['']]
# ['the', ['']]
# ['hall,', ['', '']]
# ['spotted', ['']]
# ['Harry,', ['PERSON', '']]
# ['and', ['']]
# ['hurried', ['']]
# ['over.', ['', '']]
# ['+', []]
# ['"Well', ['', '']]
# ['done,"', ['', '', '']]
# ['said', ['']]
# ['George', ['PERSON']]
# ['in', ['']]
# ['a', ['']]
# ['low', ['']]
# ['voice.', ['', '']]
# ['"Wood', ['', 'PERSON']]
# ['told', ['']]
# ['us.', ['', '']]
# ["We're", ['', '']]
# ['on', ['']]
# ['the', ['']]
# ['team', ['']]
# ['too', ['']]
# ['--', ['']]
# ['Beaters."', ['', '', '']]
# ['+', []]
# ['"I', ['', '']]
# ['tell', ['']]
# ['you,', ['', '']]
# ["we're", ['', '']]
# ['going', ['']]
# ['to', ['']]
# ['win', ['']]
# ['that', ['']]
# ['Quidditch', ['EVENT']]
# ['Cup', ['EVENT']]
# ['for', ['']]
# ['sure', ['']]
# ['this', ['DATE']]
# ['year,"', ['DATE', '', '']]
# ['said', ['']]
# ['Fred.', ['PERSON', '']]
# ['"We', ['', '']]
# ["haven't", ['', '']]
# ['won', ['']]
# ['since', ['']]
# ['Charlie', ['PERSON']]
# ['left,', ['', '']]
# ['but', ['']]
# ['this', ['']]
# ["year's", ['DATE', '']]
# ['team', ['']]
# ['is', ['']]
# ['going', ['']]
# ['to', ['']]
# ['be', ['']]
# ['brilliant.', ['', '']]
# ['You', ['']]
# ['must', ['']]
# ['be', ['']]
# ['good,', ['', '']]
# ['Harry,', ['PERSON', '']]
# ['Wood', ['']]
# ['was', ['']]
# ['almost', ['']]
# ['skipping', ['']]
# ['when', ['']]
# ['he', ['']]
# ['told', ['']]
# ['us."', ['', '', '']]
# ['+', []]
# ['"Anyway,', ['', '', '']]
# ["we've", ['', '']]
# ['got', ['']]
# ['to', ['']]
# ['go,', ['', '']]
# ['Lee', ['PERSON']]
# ['Jordan', ['PERSON']]
# ['reckons', ['']]
# ["he's", ['', '']]
# ['found', ['']]
# ['a', ['']]
# ['new', ['']]
# ['secret', ['']]
# ['passageway', ['']]
# ['out', ['']]
# ['of', ['']]
# ['the', ['']]
# ['school."', ['', '', '']]
# ['+', []]
# ['"Bet', ['', '']]
# ["it's", ['', '']]
# ['that', ['']]
# ['one', ['CARDINAL']]
# ['behind', ['']]
# ['the', ['']]
# ['statue', ['']]
# ['of', ['']]
# ['Gregory', ['PERSON']]
# ['the', ['']]
# ['Smarmy', ['']]
# ['that', ['']]
# ['we', ['']]
# ['found', ['']]
# ['in', ['']]
# ['our', ['DATE']]
# ['first', ['DATE']]
# ['week.', ['DATE', '']]
# ['See', ['']]
# ['you."', ['', '', '']]
# ['+', []]
# ['Fred', ['PERSON']]
# ['and', ['']]
# ['George', ['PERSON']]
# ['had', ['']]
# ['hardly', ['']]
# ['disappeared', ['']]
# ['when', ['']]
# ['someone', ['']]
# ['far', ['']]
# ['less', ['']]
# ['welcome', ['']]
# ['turned', ['']]
# ['up:', ['', '']]
# ['Malfoy,', ['PERSON', '']]
# ['flanked', ['']]
# ['by', ['']]
# ['Crabbe', ['PERSON']]
# ['and', ['']]
# ['Goyle.', ['PERSON', '']]
# ['+', []]
# ['"Having', ['', '']]
# ['a', ['']]
# ['last', ['']]
# ['meal,', ['', '']]
# ['Potter?', ['', '']]
# ['When', ['']]
# ['are', ['']]
# ['you', ['']]
# ['getting', ['']]
# ['the', ['']]
# ['train', ['']]
# ['back', ['']]
# ['to', ['']]
# ['the', ['']]
# ['Muggles?"', ['', '', '']]
# ['+', []]
# ['"You\'re', ['', '', '']]
# ['a', ['']]
# ['lot', ['']]
# ['braver', ['']]
# ['now', ['']]
# ['that', ['']]
# ["you're", ['', '']]
# ['back', ['']]
# ['on', ['']]
# ['the', ['']]
# ['ground', ['']]
# ['and', ['']]
# ["you've", ['', '']]
# ['got', ['']]
# ['your', ['']]
# ['little', ['']]
# ['friends', ['']]
# ['with', ['']]
# ['you,"', ['', '', '']]
# ['said', ['']]
# ['Harry', ['PERSON']]
# ['coolly.', ['', '']]
# ['There', ['']]
# ['was', ['']]
# ['of', ['']]
# ['course', ['']]
# ['nothing', ['']]
# ['at', ['']]
# ['all', ['']]
# ['little', ['']]
# ['about', ['']]
# ['Crabbe', ['PERSON']]
# ['and', ['']]
# ['Goyle,', ['PERSON', '']]
# ['but', ['']]
# ['as', ['']]
# ['the', ['']]
# ['High', ['']]
# ['Table', ['']]
# ['was', ['']]
# ['full', ['']]
# ['of', ['']]
# ['teachers,', ['', '']]
# ['neither', ['']]
# ['of', ['']]
# ['them', ['']]
# ['could', ['']]
# ['do', ['']]
# ['more', ['']]
# ['than', ['']]
# ['crack', ['']]
# ['their', ['']]
# ['knuckles', ['']]
# ['and', ['']]
# ['scowl.', ['', '']]
# ['+', []]
# ['"I\'d', ['', '', '']]
# ['take', ['']]
# ['you', ['']]
# ['on', ['']]
# ['anytime', ['']]
# ['on', ['']]
# ['my', ['']]
# ['own,"', ['', '', '']]
# ['said', ['']]
# ['Malfoy.', ['PERSON', '']]
# ['"Tonight,', ['', 'TIME', '']]
# ['if', ['']]
# ['you', ['']]
# ['want.', ['', '']]
# ["Wizard's", ['', '']]
# ['duel.', ['', '']]
# ['Wands', ['']]
# ['only', ['']]
# ['--', ['']]
# ['no', ['']]
# ['contact.', ['', '']]
# ["What's", ['', '']]
# ['the', ['']]
# ['matter?', ['', '']]
# ['Never', ['']]
# ['heard', ['']]
# ['of', ['']]
# ['a', ['']]
# ["wizard's", ['', '']]
# ['duel', ['']]
# ['before,', ['', '']]
# ['I', ['']]
# ['suppose?"', ['', '', '']]
# ['+', []]
# ['"Of', ['', '']]
# ['course', ['']]
# ['he', ['']]
# ['has,"', ['', '', '']]
# ['said', ['']]
# ['Ron,', ['PERSON', '']]
# ['wheeling', ['']]
# ['around.', ['', '']]
# ['"I\'m', ['', '', '']]
# ['his', ['']]
# ['second,', ['ORDINAL', '']]
# ["who's", ['', '']]
# ['yours?"', ['', '', '']]
# ['+', []]
# ['Malfoy', ['PERSON']]
# ['looked', ['']]
# ['at', ['']]
# ['Crabbe', ['PERSON']]
# ['and', ['']]
# ['Goyle,', ['PERSON', '']]
# ['sizing', ['']]
# ['them', ['']]
# ['up.', ['', '']]
# ['+', []]
# ['"Crabbe,"', ['', 'PERSON', '', '']]
# ['he', ['']]
# ['said.', ['', '']]
# ['"Midnight', ['', '']]
# ['all', ['']]
# ['right?', ['', '']]
# ["We'll", ['', '']]
# ['meet', ['']]
# ['you', ['']]
# ['in', ['']]
# ['the', ['']]
# ['trophy', ['']]
# ...
# ['He', ['']]
# ['was', ['']]
# ['never', ['']]
# ['going', ['']]
# ['to', ['']]
# ['meet', ['']]
# ['you', ['']]
# ['--', ['']]
# ['Filch', ['']]
# ['knew', ['']]
# ['someone', ['']]
# ['was', ['']]
# ['going', ['']]
# ['to', ['']]
# ['be', ['']]
# ['in', ['']]
# ['the', ['']]
# ['trophy', ['']]
# ['room,', ['', '']]
# ['Malfoy', ['PERSON']]
# ['must', ['']]
# ['have', ['']]
# ['tipped', ['']]
# ['him', ['']]
# ['off."', ['', '', '']]
# ['+', []]
# ['Harry', ['PERSON']]
# ['thought', ['']]
# ['she', ['']]
# ['was', ['']]
# ['probably', ['']]
# ['right,', ['', '']]
# ['but', ['']]
# ['he', ['']]
# ["wasn't", ['', '']]
# ['going', ['']]
# ['to', ['']]
# ['tell', ['']]
# ['her', ['']]
# ['that.', ['', '']]
# ['+', []]
# ['"Let\'s', ['', '', '']]
# ['go."', ['', '', '']]
# ['+', []]
# ['It', ['']]
# ["wasn't", ['', '']]
# ['going', ['']]
# ['to', ['']]
# ['be', ['']]
# ['that', ['']]
# ['simple.', ['', '']]
# ['They', ['']]
# ["hadn't", ['', '']]
# ['gone', ['']]
# ['more', ['CARDINAL']]
# ['than', ['CARDINAL']]
# ['a', ['CARDINAL']]
# ['dozen', ['CARDINAL']]
# ['paces', ['']]
# ['when', ['']]
# ['a', ['']]
# ['doorknob', ['']]
# ['rattled', ['']]
# ['and', ['']]
# ['something', ['']]
# ['came', ['']]
# ['shooting', ['']]
# ['out', ['']]
# ['of', ['']]
# ['a', ['']]
# ['classroom', ['']]
# ['in', ['']]
# ['front', ['']]
# ['of', ['']]
# ['them.', ['', '']]
# ['+', []]
# ['It', ['']]
# ['was', ['']]
# ['Peeves.', ['', '']]
# ['He', ['']]
# ['caught', ['']]
# ['sight', ['']]
# ['of', ['']]
# ['them', ['']]
# ['and', ['']]
# ['gave', ['']]
# ['a', ['']]
# ['squeal', ['']]
# ['of', ['']]
# ['delight.', ['', '']]
# ['+', []]
# ['"Shut', ['', '']]
# ['up,', ['', '']]
# ['Peeves', ['']]
# ['--', ['']]
# ['please', ['']]
# ['--', ['']]
# ["you'll", ['', '']]
# ['get', ['']]
# ['us', ['']]
# ['thrown', ['']]
# ['out."', ['', '', '']]
# ['+', []]
# ['Peeves', ['']]
# ['cackled.', ['', '']]
# ['+', []]
# ['"Wandering', ['', '']]
# ['around', ['']]
# ['at', ['']]
# ['midnight,', ['', '']]
# ['Ickle', ['PERSON']]
# ['Firsties?', ['PERSON', '']]
# ['Tut,', ['', '']]
# ['tut,', ['', '']]
# ['tut.', ['', '']]
# ['Naughty,', ['', '']]
# ['naughty,', ['', '']]
# ["you'll", ['', '']]
# ['get', ['']]
# ['caughty."', ['', '', '']]
# ['+', []]
# ['"Not', ['', '']]
# ['if', ['']]
# ['you', ['']]
# ["don't", ['', '']]
# ['give', ['']]
# ['us', ['']]
# ['away,', ['', '']]
# ['Peeves,', ['', '']]
# ['please."', ['', '', '']]
# ['+', []]
# ['"Should', ['', '']]
# ['tell', ['']]
# ['Filch,', ['', '']]
# ['I', ['']]
# ['should,"', ['', '', '']]
# ['said', ['']]
# ['Peeves', ['']]
# ['in', ['']]
# ['a', ['']]
# ['saintly', ['']]
# ['voice,', ['', '']]
# ['but', ['']]
# ['his', ['']]
# ['eyes', ['']]
# ['glittered', ['']]
# ['wickedly.', ['', '']]
# ['"It\'s', ['', '', '']]
# ['for', ['']]
# ['your', ['']]
# ['own', ['']]
# ['good,', ['', '']]
# ['you', ['']]
# ['know."', ['', '', '']]
# ['+', []]
# ['"Get', ['', '']]
# ['out', ['']]
# ['of', ['']]
# ['the', ['']]
# ['way,"', ['', '', '']]
# ['snapped', ['']]
# ['Ron,', ['PERSON', '']]
# ['taking', ['']]
# ['a', ['']]
# ['swipe', ['']]
# ['at', ['']]
# ['Peeves', ['']]
# ['--', ['']]
# ['this', ['']]
# ['was', ['']]
# ['a', ['']]
# ['big', ['']]
# ['mistake.', ['', '']]
# ['+', []]
# ['"STUDENTS', ['', '']]
# ['OUT', ['']]
# ['OF', ['']]
# ['BED!"', ['', '', '']]
# ['Peeves', ['']]
# ['bellowed,', ['', '']]
# ['"STUDENTS', ['', '']]
# ['OUT', ['']]
# ['OF', ['']]
# ['BED', ['']]
# ['DOWN', ['']]
# ['THE', ['']]
# ['CHARMS', ['']]
# ['CORRIDOR!"', ['', '', '']]
# ['+', []]
# ['Ducking', ['']]
# ['under', ['']]
# ['Peeves,', ['', '']]
# ['they', ['']]
# ['ran', ['']]
# ['for', ['']]
# ['their', ['']]
# ['lives,', ['', '']]
# ['right', ['']]
# ['to', ['']]
# ['the', ['']]
# ['end', ['']]
# ['of', ['']]
# ['the', ['']]
# ['corridor', ['']]
# ['where', ['']]
# ['they', ['']]
# ['slammed', ['']]
# ['into', ['']]
# ['a', ['']]
# ['door', ['']]
# ['--', ['']]
# ['and', ['']]
# ['it', ['']]
# ['was', ['']]
# ['locked.', ['', '']]
# ['+', []]
# ['"This', ['', '']]
# ['is', ['']]
# ['it!"', ['', '', '']]
# ['Ron', ['PERSON']]
# ['moaned,', ['', '']]
# ['as', ['']]
# ['they', ['']]
# ['pushed', ['']]
# ['helplessly', ['']]
# ['at', ['']]
# ['the', ['']]
# ['door,', ['', '']]
# ['"We\'re', ['', '', '']]
# ['done', ['']]
# ['for!', ['', '']]
# ['This', ['']]
# ['is', ['']]
# ['the', ['']]
# ['end!"', ['', '', '']]
# ['+', []]
# ['They', ['']]
# ['could', ['']]
# ['hear', ['']]
# ['footsteps,', ['', '']]
# ['Filch', ['ORG']]
# ['running', ['']]
# ['as', ['']]
# ['fast', ['']]
# ['as', ['']]
# ['he', ['']]
# ['could', ['']]
# ['toward', ['']]
# ["Peeves's", ['', '']]
# ['shouts.', ['', '']]
# ['+', []]
# ['"Oh,', ['', '', '']]
# ['move', ['']]
# ['over,"', ['', '', '']]
# ['Hermione', ['']]
# ['snarled.', ['', '']]
# ['She', ['']]
# ['grabbed', ['']]
# ["Harry's", ['PERSON', '']]
# ['wand,', ['', '']]
# ['tapped', ['']]
# ['the', ['']]
# ['lock,', ['', '']]
# ['and', ['']]
# ['whispered,', ['', '']]
# ['"Alohomora!"', ['', '', '', '']]
# ['+', []]
# ['The', ['']]
# ['lock', ['']]
# ['clicked', ['']]
# ['and', ['']]
# ['the', ['']]
# ['door', ['']]
# ['swung', ['']]
# ['open', ['']]
# ['--', ['']]
# ['they', ['']]
# ['piled', ['']]
# ['through', ['']]
# ['it,', ['', '']]
# ['shut', ['']]
# ['it', ['']]
# ['quickly,', ['', '']]
# ['and', ['']]
# ['pressed', ['']]
# ['their', ['']]
# ['ears', ['']]
# ['against', ['']]
# ['it,', ['', '']]
# ['listening.', ['', '']]
# ['+', []]
# ['"Which', ['', '']]
# ['way', ['']]
# ['did', ['']]
# ['they', ['']]
# ['go,', ['', '']]
# ['Peeves?"', ['', '', '']]
# ['Filch', ['']]
# ['was', ['']]
# ['saying.', ['', '']]
# ['"Quick,', ['', '', '']]
# ['tell', ['']]
# ['me."', ['', '', '']]
# ['"Say', ['', '']]
# ['\'please.\'"', ['', '', '', '', '']]
# ['+', []]
# ['"Don\'t', ['', '', '']]
# ['mess', ['']]
# ['with', ['']]
# ['me,', ['', '']]
# ['Peeves,', ['', '']]
# ['now', ['']]
# ['where', ['']]
# ['did', ['']]
# ['they', ['']]
# ['go?"', ['', '', '']]
# ['"Shan\'t', ['', 'WORK_OF_ART', 'WORK_OF_ART']]
# ['say', ['']]
# ['nothing', ['']]
# ['if', ['']]
# ['you', ['']]
# ["don't", ['', '']]
# ['say', ['']]
# ['please,"', ['', '', '']]
# ['said', ['']]
# ['Peeves', ['']]
# ['in', ['']]
# ['his', ['']]
# ['annoying', ['']]
# ['singsong', ['']]
# ['voice.', ['', '']]
# ['"All', ['', '']]
# ['right', ['']]
# ['--', ['']]
# ['please."', ['', '', '']]
# ['+', []]
# ['"NOTHING!', ['', '', '']]
# ['Ha', ['']]
# ['haaa!', ['', '']]
# ['Told', ['']]
# ['you', ['']]
# ['I', ['']]
# ["wouldn't", ['', '']]
# ['say', ['']]
# ['nothing', ['']]
# ['if', ['']]
# ['you', ['']]
# ["didn't", ['', '']]
# ['say', ['']]
# ['please!', ['', '']]
# ['Ha', ['']]
# ['ha!', ['', '']]
# ['Haaaaaa!"', ['', '', '']]
# ['And', ['']]
# ['they', ['']]
# ['heard', ['']]
# ['the', ['']]
# ['sound', ['']]
# ['of', ['']]
# ['Peeves', ['']]
# ['whooshing', ['']]
# ['away', ['']]
# ['and', ['']]
# ['Filch', ['PERSON']]
# ['cursing', ['']]
# ['in', ['']]
# ['rage.', ['', '']]
# ['+', []]
# ['"He', ['', '']]
# ['thinks', ['']]
# ['this', ['']]
# ['door', ['']]
# ['is', ['']]
# ['locked,"', ['', '', '']]
# ['Harry', ['PERSON']]
# ['whispered.', ['', '']]
# ['"I', ['', '']]
# ['think', ['']]
# ["we'll", ['', '']]
# ['be', ['']]
# ['okay', ['']]
# ['--', ['']]
# ['get', ['']]
# ['off,', ['', '']]
# ['Neville!"', ['PERSON', '', '']]
# ['For', ['']]
# ['Neville', ['PERSON']]
# ['had', ['']]
# ['been', ['']]
# ['tugging', ['']]
# ['on', ['']]
# ['the', ['']]
# ['sleeve', ['']]
# ['of', ['']]
# ["Harry's", ['PERSON', '']]
# ['bathrobe', ['']]
# ['for', ['']]
# ['the', ['TIME']]
# ['last', ['TIME']]
# ['minute.', ['TIME', '']]
# ['"What?"', ['', '', '', '']]
# ['+', []]
# ['Harry', ['PERSON']]
# ['turned', ['']]
# ['around', ['']]
# ['--', ['']]
# ['and', ['']]
# ['saw,', ['', '']]
# ['quite', ['']]
# ['clearly,', ['', '']]
# ['what.', ['', '']]
# ['For', ['']]
# ['a', ['']]
# ['moment,', ['', '']]
# ['he', ['']]
# ['was', ['']]
# ['sure', ['']]
# ["he'd", ['', '']]
# ['walked', ['']]
# ['into', ['']]
# ['a', ['']]
# ['nightmare', ['']]
# ['--', ['']]
# ['this', ['']]
# ['was', ['']]
# ['too', ['']]
# ['much,', ['', '']]
# ['on', ['']]
# ['top', ['']]
# ['of', ['']]
# ['everything', ['']]
# ['that', ['']]
# ['had', ['']]
# ['happened', ['']]
# ['so', ['']]
# ['far.', ['', '']]
# ['+', []]
# ['They', ['']]
# ["weren't", ['', '']]
# ['in', ['']]
# ['a', ['']]
# ['room,', ['', '']]
# ['as', ['']]
# ['he', ['']]
# ['had', ['']]
# ['supposed.', ['', '']]
# ['They', ['']]
# ['were', ['']]
# ['in', ['']]
# ['a', ['']]
# ['corridor.', ['', '']]
# ['The', ['']]
# ['forbidden', ['']]
# ['corridor', ['']]
# ['on', ['']]
# ['the', ['']]
# ['third', ['ORDINAL']]
# ['floor.', ['', '']]
# ['And', ['']]
# ['now', ['']]
# ['they', ['']]
# ['knew', ['']]
# ['why', ['']]
# ['it', ['']]
# ['was', ['']]
# ['forbidden.', ['', '']]
# ['+', []]
# ['They', ['']]
# ['were', ['']]
# ['looking', ['']]
# ['straight', ['']]
# ['into', ['']]
# ['the', ['']]
# ['eyes', ['']]
# ['of', ['']]
# ['a', ['']]
# ['monstrous', ['']]
# ['dog,', ['', '']]
# ['a', ['']]
# ['dog', ['']]
# ['that', ['']]
# ['filled', ['']]
# ['the', ['']]
# ['whole', ['']]
# ['space', ['']]
# ['between', ['']]
# ['ceiling', ['']]
# ['and', ['']]
# ['floor.', ['', '']]
# ['It', ['']]
# ['had', ['']]
# ['three', ['CARDINAL']]
# ['heads.', ['', '']]
# ['Three', ['CARDINAL']]
# ['pairs', ['']]
# ['of', ['']]
# ['rolling,', ['', '']]
# ['mad', ['']]
# ['eyes;', ['', '']]
# ['three', ['CARDINAL']]
# ['noses,', ['', '']]
# ['twitching', ['']]
# ['and', ['']]
# ['quivering', ['']]
# ['in', ['']]
# ['their', ['']]
# ['direction;', ['', '']]
# ['three', ['CARDINAL']]
# ['drooling', ['']]
# ['mouths,', ['', '']]
# ['saliva', ['']]
# ['hanging', ['']]
# ['in', ['']]
# ['slippery', ['']]
# ['ropes', ['']]
# ['from', ['']]
# ['yellowish', ['']]
# ['fangs.', ['', '']]
# ['+', []]
# ['It', ['']]
# ['was', ['']]
# ['standing', ['']]
# ['quite', ['']]
# ['still,', ['', '']]
# ['all', ['']]
# ['six', ['CARDINAL']]
# ['eyes', ['']]
# ['staring', ['']]
# ['at', ['']]
# ['them,', ['', '']]
# ['and', ['']]
# ['Harry', ['PERSON']]
# ['knew', ['']]
# ['that', ['']]
# ['the', ['']]
# ['only', ['']]
# ['reason', ['']]
# ['they', ['']]
# ["weren't", ['', '']]
# ['already', ['']]
# ['dead', ['']]
# ['was', ['']]
# ['that', ['']]
# ['their', ['']]
# ['sudden', ['']]
# ['appearance', ['']]
# ['had', ['']]
# ['taken', ['']]
# ['it', ['']]
# ['by', ['']]
# ['surprise,', ['', '']]
# ['but', ['']]
# ['it', ['']]
# ['was', ['']]
# ['quickly', ['']]
# ['getting', ['']]
# ['over', ['']]
# ['that,', ['', '']]
# ['there', ['']]
# ['was', ['']]
# ['no', ['']]
# ['mistaking', ['']]
# ['what', ['']]
# ['those', ['']]
# ['thunderous', ['']]
# ['growls', ['']]
# ['meant.', ['', '']]
# ['+', []]
# ['Harry', ['PERSON']]
# ['groped', ['']]
# ['for', ['']]
# ['the', ['']]
# ['doorknob', ['']]
# ['--', ['']]
# ['between', ['']]
# ['Filch', ['ORG']]
# ['and', ['']]
# ['death,', ['', '']]
# ["he'd", ['', '']]
# ['take', ['']]
# ['Filch.', ['ORG', '']]
# ['+', []]
# ['They', ['']]
# ['fell', ['']]
# ['backward', ['']]
# ['--', ['']]
# ['Harry', ['PERSON']]
# ['slammed', ['']]
# ['the', ['']]
# ['door', ['']]
# ['shut,', ['', '']]
# ['and', ['']]
# ['they', ['']]
# ['ran,', ['', '']]
# ['they', ['']]
# ['almost', ['']]
# ['flew,', ['', '']]
# ['back', ['']]
# ['down', ['']]
# ['the', ['']]
# ['corridor.', ['', '']]
# ['Filch', ['']]
# ['must', ['']]
# ['have', ['']]
# ['hurried', ['']]
# ['off', ['']]
# ['to', ['']]
# ['look', ['']]
# ['for', ['']]
# ['them', ['']]
# ['somewhere', ['']]
# ['else,', ['', '']]
# ['because', ['']]
# ['they', ['']]
# ["didn't", ['', '']]
# ['see', ['']]
# ['him', ['']]
# ['anywhere,', ['', '']]
# ['but', ['']]
# ['they', ['']]
# ['hardly', ['']]
# ['cared', ['']]
# ['--', ['']]
# ['all', ['']]
# ['they', ['']]
# ['wanted', ['']]
# ['to', ['']]
# ['do', ['']]
# ['was', ['']]
# ['put', ['']]
# ['as', ['']]
# ['much', ['']]
# ['space', ['']]
# ['as', ['']]
# ['possible', ['']]
# ['between', ['']]
# ['them', ['']]
# ['and', ['']]
# ['that', ['']]
# ['monster.', ['', '']]
# ['They', ['']]
# ["didn't", ['', '']]
# ['stop', ['']]
# ['running', ['']]
# ['until', ['']]
# ['they', ['']]
# ['reached', ['']]
# ['the', ['']]
# ['portrait', ['']]
# ['of', ['']]
# ['the', ['']]
# ['Fat', ['']]
# ['Lady', ['']]
# ['on', ['']]
# ['the', ['']]
# ['seventh', ['ORDINAL']]
# ['floor.', ['', '']]
# ['+', []]
# ['"Where', ['', '']]
# ['on', ['']]
# ['earth', ['']]
# ['have', ['']]
# ['you', ['']]
# ['all', ['']]
# ['been?"', ['', '', '']]
# ['she', ['']]
# ['asked,', ['', '']]
# ['looking', ['']]
# ['at', ['']]
# ['their', ['']]
# ['bathrobes', ['']]
# ['hanging', ['']]
# ['off', ['']]
# ['their', ['']]
# ['shoulders', ['']]
# ['and', ['']]
# ['their', ['']]
# ['flushed,', ['', '']]
# ['sweaty', ['']]
# ['faces.', ['', '']]
# ['+', []]
# ['"Never', ['', '']]
# ['mind', ['']]
# ['that', ['']]
# ['--', ['']]
# ['pig', ['']]
# ['snout,', ['', '']]
# ['pig', ['']]
# ['snout,"', ['', '', '']]
# ['panted', ['']]
# ['Harry,', ['PERSON', '']]
# ['and', ['']]
# ['the', ['']]
# ['portrait', ['']]
# ['swung', ['']]
# ['forward.', ['', '']]
# ['They', ['']]
# ['scrambled', ['']]
# ['into', ['']]
# ['the', ['']]
# ['common', ['']]
# ['room', ['']]
# ['and', ['']]
# ['collapsed,', ['', '']]
# ['trembling,', ['', '']]
# ['into', ['']]
# ['armchairs.', ['', '']]
# ['+', []]
# ['It', ['']]
# ['was', ['']]
# ['a', ['']]
# ['while', ['']]
# ['before', ['']]
# ['any', ['']]
# ['of', ['']]
# ['them', ['']]
# ['said', ['']]
# ['anything.', ['', '']]
# ['Neville,', ['PERSON', '']]
# ['indeed,', ['', '']]
# ['looked', ['']]
# ['as', ['']]
# ['if', ['']]
# ["he'd", ['', '']]
# ['never', ['']]
# ['speak', ['']]
# ['again.', ['', '']]
# ['+', []]
# ['"What', ['', '']]
# ['do', ['']]
# ['they', ['']]
# ['think', ['']]
# ["they're", ['', '']]
# ['doing,', ['', '']]
# ['keeping', ['']]
# ['a', ['']]
# ['thing', ['']]
# ['like', ['']]
# ['that', ['']]
# ['locked', ['']]
# ['up', ['']]
# ['in', ['']]
# ['a', ['']]
# ['school?"', ['', '', '']]
# ['said', ['']]
# ['Ron', ['PERSON']]
# ['finally.', ['', '']]
# ['"If', ['', '']]
# ['any', ['']]
# ['dog', ['']]
# ['needs', ['']]
# ['exercise,', ['', '']]
# ['that', ['']]
# ['one', ['']]
# ['does."', ['', '', '']]
# ['+', []]
# ['Hermione', ['']]
# ['had', ['']]
# ['got', ['']]
# ['both', ['']]
# ['her', ['']]
# ['breath', ['']]
# ['and', ['']]
# ['her', ['']]
# ['bad', ['']]
# ['temper', ['']]
# ['back', ['']]
# ['again.', ['', '']]
# ['+', []]
# ['"You', ['', '']]
# ["don't", ['', '']]
# ['use', ['']]
# ['your', ['']]
# ['eyes,', ['', '']]
# ['any', ['']]
# ['of', ['']]
# ['you,', ['', '']]
# ['do', ['']]
# ['you?"', ['', '', '']]
# ['she', ['']]
# ['snapped.', ['', '']]
# ['"Didn\'t', ['', '', '']]
# ['you', ['']]
# ['see', ['']]
# ['what', ['']]
# ['it', ['']]
# ['was', ['']]
# ['standing', ['']]
# ['on?"', ['', '', '']]
# ['+', []]
# ['"The', ['', '']]
# ['floor?"', ['', '', '']]
# ['Harry', ['PERSON']]
# ['suggested.', ['', '']]
# ['"I', ['', '']]
# ["wasn't", ['', '']]
# ['looking', ['']]
# ['at', ['']]
# ['its', ['']]
# ['feet,', ['', '']]
# ['I', ['']]
# ['was', ['']]
# ['too', ['']]
# ['busy', ['']]
# ['with', ['']]
# ['its', ['']]
# ['heads."', ['', '', '']]
# ['+', []]
# ['"No,', ['', '', '']]
# ['not', ['']]
# ['the', ['']]
# ['floor.', ['', '']]
# ['It', ['']]
# ['was', ['']]
# ['standing', ['']]
# ['on', ['']]
# ['a', ['']]
# ['trapdoor.', ['', '']]
# ["It's", ['', '']]
# ['obviously', ['']]
# ['guarding', ['']]
# ['something."', ['', '', '']]
# ['+', []]
# ['She', ['']]
# ['stood', ['']]
# ['up,', ['', '']]
# ['glaring', ['']]
# ['at', ['']]
# ['them.', ['', '']]
# ['+', []]
# ['"I', ['', '']]
# ['hope', ['']]
# ["you're", ['', '']]
# ['pleased', ['']]
# ['with', ['']]
# ['yourselves.', ['', '']]
# ['We', ['']]
# ['could', ['']]
# ['all', ['']]
# ['have', ['']]
# ['been', ['']]
# ['killed', ['']]
# ['--', ['']]
# ['or', ['']]
# ['worse,', ['', '']]
# ['expelled.', ['', '']]
# ['Now,', ['', '']]
# ['if', ['']]
# ['you', ['']]
# ["don't", ['', '']]
# ['mind,', ['', '']]
# ["I'm", ['', '']]
# ['going', ['']]
# ['to', ['']]
# ['bed."', ['', '', '']]
# ['+', []]
# ['Ron', ['PERSON']]
# ['stared', ['']]
# ['after', ['']]
# ['her,', ['', '']]
# ['his', ['']]
# ['mouth', ['']]
# ['open.', ['', '']]
# ['"No,', ['', '', '']]
# ['we', ['']]
# ["don't", ['', '']]
# ['mind,"', ['', '', '']]
# ['he', ['']]
# ['said.', ['', '']]
# ['"You\'d', ['', '', '']]
# ['think', ['']]
# ['we', ['']]
# ['dragged', ['']]
# ['her', ['']]
# ['along,', ['', '']]
# ["wouldn't", ['', '']]
# ['you?"', ['', '', '']]
# ['+', []]
# ['But', ['']]
# ['Hermione', ['']]
# ['had', ['']]
# ['given', ['']]
# ['Harry', ['PERSON']]
# ['something', ['']]
# ['else', ['']]
# ['to', ['']]
# ['think', ['']]
# ['about', ['']]
# ['as', ['']]
# ['he', ['']]
# ['climbed', ['']]
# ['back', ['']]
# ['into', ['']]
# ['bed.', ['', '']]
# ['The', ['']]
# ['dog', ['']]
# ['was', ['']]
# ['guarding', ['']]
# ['something.', ['', '']]
# ['.', ['']]
# ['.', ['']]
# ['.', ['']]
# ['What', ['']]
# ['had', ['']]
# ['Hagrid', ['']]
# ['said?', ['', '']]
# ['Gringotts', ['PERSON']]
# ['was', ['']]
# ['the', ['']]
# ['safest', ['']]
# ['place', ['']]
# ['in', ['']]
# ['the', ['']]
# ['world', ['']]
# ['for', ['']]
# ['something', ['']]
# ['you', ['']]
# ['wanted', ['']]
# ['to', ['']]
# ['hide', ['']]
# ['--', ['']]
# ['except', ['']]
# ['perhaps', ['']]
# ['Hogwarts.', ['PERSON', '']]
# ['+', []]
# ['It', ['']]
# ['looked', ['']]
# ['as', ['']]
# ['though', ['']]
# ['Harry', ['PERSON']]
# ['had', ['']]
# ['found', ['']]
# ['out', ['']]
# ['where', ['']]
# ['the', ['']]
# ['grubby', ['']]
# ['little', ['']]
# ['package', ['']]
# ['from', ['']]
# ['vault', ['']]
# ['seven', ['CARDINAL']]
# ['hundred', ['CARDINAL']]
# ['and', ['CARDINAL']]
# ['thirteen', ['CARDINAL']]
# ['was.', ['', '']]
# ['+', []]
